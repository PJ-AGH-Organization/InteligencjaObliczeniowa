# %% [markdown]
# # Rolling Ball Navigator - TD3
#
# Projekt 5 z przedmiotu Inteligencja Obliczeniowa.
# Środowisko: własne `RollingBallEnv` (ciągłe stany i akcje).
# Algorytm: **TD3 (Twin Delayed DDPG)** z biblioteki `stable-baselines3`.

# %% [markdown]
# ## 1. Opis środowiska i algorytmu
#
# **Środowisko - RollingBallEnv.** Kulka (promień 12 px) toczy się po planszy 600×600 px z sześcioma prostokątnymi przeszkodami. Agent obserwuje 13 wartości ciągłych: znormalizowaną prędkość (`vel_x`, `vel_y`), jednostkowy wektor kierunku do celu (`goal_dx`, `goal_dy`), znormalizowaną odległość do celu (`goal_dist`) oraz odczyty 8 promieni raycasting rozmieszczonych co 45°, mierzących odległość do najbliższej ściany lub przeszkody. Przestrzeń akcji jest ciągła - dwuwymiarowy wektor siły **Box([−1,−1], [1,1])** przykładanej do kulki. Epizod kończy się sukcesem (`terminated`), gdy kulka dotknie celu, lub po 500 krokach (`truncated`). Kształtowanie nagrody: **−0.01 + 0.02·(prev_dist − dist)** za każdy krok plus **+50** za dotarcie do celu.
#
# **Algorytm - TD3.** TD3 (Twin Delayed Deep Deterministic Policy Gradient, Fujimoto i in. 2018) jest algorytmem off-policy przeznaczonym wyłącznie do ciągłych przestrzeni akcji. Wprowadza trzy usprawnienia względem DDPG: (1) **Twin Critics** - dwa niezależne krytycy Q1 i Q2; do obliczenia celu Bellmana używane jest minimum z ich oszacowań, co eliminuje optymistyczne przeszacowanie wartości Q; (2) **Delayed Policy Update** - aktor aktualizowany co `policy_delay` kroków krytyków, co stabilizuje parę aktor–krytycy; (3) **Target Policy Smoothing** - do docelowej akcji dodawany jest clippowany szum Gaussa, co wygładza powierzchnię wartości i zmniejsza podatność na strome lokalne maksima. Agent zbiera przejścia (s, a, r, s′) do buforu replay i losowo próbkuje mini-batche do aktualizacji sieci.

# %%
import os
import sys
import time
import warnings
warnings.filterwarnings('ignore')

if '.' not in sys.path:
    sys.path.insert(0, '.')

import numpy as np
import matplotlib.pyplot as plt

from rolling_ball_env import RollingBallEnv
from stable_baselines3 import TD3
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import EvalCallback

os.makedirs('logs',   exist_ok=True)
os.makedirs('models', exist_ok=True)

TOTAL_TIMESTEPS = 200_000
EVAL_FREQ       = 10_000
N_EVAL_EPS      = 10
N_SEEDS         = 10

print('Importy OK.')
print(f'TOTAL_TIMESTEPS={TOTAL_TIMESTEPS:,}, EVAL_FREQ={EVAL_FREQ:,}, N_SEEDS={N_SEEDS}')
# Out:
# Importy OK.
# TOTAL_TIMESTEPS=200,000, EVAL_FREQ=10,000, N_SEEDS=10

# %%
# ── Pomiar czasu kroku i epizodu ──────────────────────────────────────────────
_env = RollingBallEnv()
_obs, _ = _env.reset(seed=42)

_N = 5_000
_t0 = time.perf_counter()
for _ in range(_N):
    _a = _env.action_space.sample()
    _obs, _, _d, _tr, _ = _env.step(_a)
    if _d or _tr:
        _obs, _ = _env.reset()
_step_us = (time.perf_counter() - _t0) / _N * 1e6

_N_EP = 200
_ep_lens = []
_t0 = time.perf_counter()
for _ in range(_N_EP):
    _obs, _ = _env.reset()
    _n = 0
    while True:
        _obs, _, _d, _tr, _ = _env.step(_env.action_space.sample())
        _n += 1
        if _d or _tr:
            break
    _ep_lens.append(_n)
_ep_ms = (time.perf_counter() - _t0) / _N_EP * 1e3
_env.close()

print(f'Czas jednego kroku:    {_step_us:.2f} µs  ({1e6/_step_us:.0f} kroków/s)')
print(f'Czas jednego epizodu:  {_ep_ms:.2f} ms  (śr. {np.mean(_ep_lens):.0f} kroków/epizod, losowe akcje)')
print(f'Szac. czas 1 seeda:    ~{TOTAL_TIMESTEPS * _step_us / 1e6:.0f} s  (sam krok, bez narzutu SB3/ewaluacji)')
# Out:
# Czas jednego kroku:    121.78 µs  (8212 kroków/s)
# Czas jednego epizodu:  59.47 ms  (śr. 499 kroków/epizod, losowe akcje)
# Szac. czas 1 seeda:    ~24 s  (sam krok, bez narzutu SB3/ewaluacji)

# %% [markdown]
# ## 2. Porównanie zestawów hiperparametrów
#
# Testujemy trzy konfiguracje różniące się **współczynnikiem uczenia** i **rozmiarem mini-batcha**. Pozostałe parametry są stałe: `gamma=0.99`, `tau=0.005`, `policy_delay=2`, `learning_starts=10 000`, `buffer_size=300 000`, `net_arch=[256, 256]`. Każda konfiguracja uruchamiana **10 razy** z różnymi seedami (0–9), każde uruchomienie przez **200 000 kroków**. Ewaluacja co 10 000 kroków, 10 epizodów deterministycznych.
#
# | Konfiguracja | `learning_rate` | `batch_size` | Charakterystyka |
# |---|---|---|---|
# | **A - Baseline** | 3×10⁻⁴ | 256 | Domyślne wartości zbliżone do zaleceń autorów TD3 |
# | **B - Wysoki LR** | 10⁻³ | 256 | 3× szybsze aktualizacje wag; ryzyko niestabilności krytyków |
# | **C - Niski LR + mały batch** | 10⁻⁴ | 128 | Zachowawcze aktualizacje; wolniejsza konwergencja |

# %%
def run_experiment(config_name, model_kwargs, log_base='logs',
                   n_seeds=N_SEEDS, total_timesteps=TOTAL_TIMESTEPS):
    """Trenuje TD3 dla jednej konfiguracji × n_seeds seedów.
    Wyniki są buforowane - ponowne uruchomienie wczytuje cache."""
    config_dir = os.path.join(log_base, config_name)
    os.makedirs(config_dir, exist_ok=True)
    all_results = []

    expected_evals = total_timesteps // EVAL_FREQ

    for seed in range(n_seeds):
        seed_dir  = os.path.join(config_dir, f'seed_{seed}')
        eval_path = os.path.join(seed_dir, 'evaluations.npz')

        if os.path.exists(eval_path):
            cached = dict(np.load(eval_path))
            if len(cached['timesteps']) >= expected_evals:
                all_results.append(cached)
                print(f'  [{config_name}] seed {seed}: wczytano z cache')
                continue
            else:
                print(f'  [{config_name}] seed {seed}: cache nieaktualne '
                      f'({len(cached["timesteps"])} != {expected_evals} ewal.), retrenuje')

        os.makedirs(seed_dir, exist_ok=True)
        train_env = RollingBallEnv()
        eval_env  = Monitor(RollingBallEnv())

        model = TD3('MlpPolicy', train_env, seed=seed, verbose=0, **model_kwargs)
        cb = EvalCallback(
            eval_env,
            best_model_save_path=seed_dir,
            log_path=seed_dir,
            eval_freq=EVAL_FREQ,
            n_eval_episodes=N_EVAL_EPS,
            deterministic=True,
            render=False,
        )
        model.learn(total_timesteps=total_timesteps, callback=cb)
        train_env.close()
        eval_env.close()

        all_results.append(dict(np.load(eval_path)))
        print(f'  [{config_name}] seed {seed}: done')

    return all_results


def aggregate(results_list):
    """Zwraca (timesteps, mean, std) uśrednione po seedach."""
    arrays = [r['results'].mean(axis=1) for r in results_list]
    min_len = min(len(a) for a in arrays)
    if min_len < len(arrays[0]):
        print(f'  [aggregate] uwaga: różne długości checkpointów – przycinanie do {min_len}')
    ts = results_list[0]['timesteps'][:min_len]
    per_seed = np.array([a[:min_len] for a in arrays])
    return ts, per_seed.mean(axis=0), per_seed.std(axis=0)


def plot_curves(configs_data, labels, title, save_path=None):
    fig, ax = plt.subplots(figsize=(11, 5))
    colors = plt.cm.tab10.colors
    for i, (data, label) in enumerate(zip(configs_data, labels)):
        ts, mean, std = aggregate(data)
        ax.plot(ts, mean, label=label, color=colors[i], linewidth=1.8)
        ax.fill_between(ts, mean - std, mean + std, alpha=0.18, color=colors[i])
    ax.axhline(0, color='gray', linewidth=0.7, linestyle='--')
    ax.set_xlabel('Kroki (timesteps)')
    ax.set_ylabel('Nagroda epizodu (śr. z 10 ep. ewaluacyjnych)')
    ax.set_title(title)
    ax.legend()
    ax.grid(alpha=0.3)
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=150)
    plt.show()

# %%
COMMON = dict(
    gamma=0.99, tau=0.005, policy_delay=2,
    learning_starts=10_000, buffer_size=300_000,
    policy_kwargs={'net_arch': [256, 256]},
)

configs = {
    'A_baseline':       {**COMMON, 'learning_rate': 3e-4, 'batch_size': 256},
    'B_wysoki_lr':      {**COMMON, 'learning_rate': 1e-3, 'batch_size': 256},
    'C_niski_lr_batch': {**COMMON, 'learning_rate': 1e-4, 'batch_size': 128},
}

print(f'Porównanie hiperparametrów: {len(configs)} konfiguracje × {N_SEEDS} seedów × {TOTAL_TIMESTEPS:,} kroków')
print(f'Łącznie ≈ {len(configs) * N_SEEDS * TOTAL_TIMESTEPS / 1e6:.1f} M kroków\n')

results = {}
for name, kwargs in configs.items():
    print(f'--- Konfiguracja {name} ---')
    results[name] = run_experiment(name, kwargs)
    print()

print('Trening zakończony.')
# Out:
# Porównanie hiperparametrów: 3 konfiguracje × 10 seedów × 200,000 kroków
# Łącznie ≈ 6.0 M kroków
#
# --- Konfiguracja A_baseline ---
#   [A_baseline] seed 0: wczytano z cache
# Eval num_timesteps=10000, episode_reward=-5.09 +/- 1.25
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=26.54 +/- 28.88
# Episode length: 313.90 +/- 190.65
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=37.13 +/- 27.69
# Episode length: 220.90 +/- 188.18
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=36.96 +/- 25.13
# Episode length: 227.50 +/- 192.03
# Eval num_timesteps=50000, episode_reward=50.01 +/- 18.31
# Episode length: 187.70 +/- 121.92
# New best mean reward!
# Eval num_timesteps=60000, episode_reward=37.55 +/- 26.43
# Episode length: 228.20 +/- 180.42
# Eval num_timesteps=70000, episode_reward=48.10 +/- 17.84
# Episode length: 129.10 +/- 131.83
# Eval num_timesteps=80000, episode_reward=55.73 +/- 1.98
# Episode length: 147.90 +/- 75.65
# New best mean reward!
# Eval num_timesteps=90000, episode_reward=50.37 +/- 15.78
# Episode length: 155.90 +/- 122.73
# Eval num_timesteps=100000, episode_reward=55.54 +/- 1.88
# Episode length: 104.80 +/- 34.29
# Eval num_timesteps=110000, episode_reward=48.57 +/- 17.48
# Episode length: 139.00 +/- 124.81
# Eval num_timesteps=120000, episode_reward=48.30 +/- 17.75
# Episode length: 115.20 +/- 130.72
# Eval num_timesteps=130000, episode_reward=44.59 +/- 23.44
# Episode length: 187.50 +/- 158.94
# Eval num_timesteps=140000, episode_reward=55.78 +/- 1.91
# Episode length: 107.40 +/- 30.94
# New best mean reward!
# Eval num_timesteps=150000, episode_reward=54.35 +/- 2.44
# Episode length: 73.70 +/- 36.39
# Eval num_timesteps=160000, episode_reward=49.51 +/- 17.31
# Episode length: 137.70 +/- 123.57
# Eval num_timesteps=170000, episode_reward=55.44 +/- 2.08
# Episode length: 91.20 +/- 26.29
# Eval num_timesteps=180000, episode_reward=54.92 +/- 3.07
# Episode length: 115.40 +/- 48.26
# Eval num_timesteps=190000, episode_reward=55.28 +/- 2.18
# Episode length: 106.90 +/- 54.09
# Eval num_timesteps=200000, episode_reward=55.70 +/- 2.67
# Episode length: 95.50 +/- 38.89
#   [A_baseline] seed 1: done
# Eval num_timesteps=10000, episode_reward=-6.41 +/- 1.82
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=19.13 +/- 26.50
# Episode length: 314.30 +/- 227.49
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=36.16 +/- 25.73
# Episode length: 201.50 +/- 200.68
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=41.99 +/- 24.91
# Episode length: 170.80 +/- 168.07
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=25.61 +/- 28.33
# Episode length: 315.70 +/- 187.22
# Eval num_timesteps=60000, episode_reward=30.93 +/- 29.32
# Episode length: 247.30 +/- 209.06
# Eval num_timesteps=70000, episode_reward=30.65 +/- 28.40
# Episode length: 258.70 +/- 203.40
# Eval num_timesteps=80000, episode_reward=49.00 +/- 18.18
# Episode length: 143.00 +/- 131.46
# New best mean reward!
# Eval num_timesteps=90000, episode_reward=37.01 +/- 27.55
# Episode length: 238.20 +/- 181.00
# Eval num_timesteps=100000, episode_reward=43.29 +/- 23.14
# Episode length: 212.30 +/- 151.73
# Eval num_timesteps=110000, episode_reward=32.00 +/- 28.86
# Episode length: 264.40 +/- 194.60
# Eval num_timesteps=120000, episode_reward=33.60 +/- 28.89
# Episode length: 277.20 +/- 187.45
# Eval num_timesteps=130000, episode_reward=50.69 +/- 18.02
# Episode length: 203.50 +/- 114.55
# New best mean reward!
# Eval num_timesteps=140000, episode_reward=43.54 +/- 23.33
# Episode length: 179.70 +/- 164.28
# Eval num_timesteps=150000, episode_reward=43.83 +/- 22.64
# Episode length: 181.30 +/- 161.43
# Eval num_timesteps=160000, episode_reward=53.53 +/- 1.97
# Episode length: 59.00 +/- 29.18
# New best mean reward!
# Eval num_timesteps=170000, episode_reward=48.84 +/- 17.62
# Episode length: 136.70 +/- 130.97
# Eval num_timesteps=180000, episode_reward=49.41 +/- 17.31
# Episode length: 134.50 +/- 132.02
# Eval num_timesteps=190000, episode_reward=49.46 +/- 18.04
# Episode length: 132.10 +/- 124.07
# Eval num_timesteps=200000, episode_reward=48.79 +/- 17.81
# Episode length: 140.10 +/- 129.09
#   [A_baseline] seed 2: done
# Eval num_timesteps=10000, episode_reward=-4.98 +/- 1.67
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=20.87 +/- 27.66
# Episode length: 345.50 +/- 190.87
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=44.19 +/- 21.98
# Episode length: 175.00 +/- 164.01
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=37.87 +/- 25.44
# Episode length: 213.60 +/- 191.83
# Eval num_timesteps=50000, episode_reward=37.32 +/- 26.13
# Episode length: 206.70 +/- 193.78
# Eval num_timesteps=60000, episode_reward=48.81 +/- 18.18
# Episode length: 159.50 +/- 127.01
# New best mean reward!
# Eval num_timesteps=70000, episode_reward=55.20 +/- 2.12
# Episode length: 112.20 +/- 62.68
# New best mean reward!
# Eval num_timesteps=80000, episode_reward=47.70 +/- 16.87
# Episode length: 129.70 +/- 129.01
# Eval num_timesteps=90000, episode_reward=43.36 +/- 23.27
# Episode length: 176.40 +/- 167.35
# Eval num_timesteps=100000, episode_reward=50.22 +/- 17.94
# Episode length: 154.50 +/- 123.59
# Eval num_timesteps=110000, episode_reward=49.62 +/- 18.23
# Episode length: 142.00 +/- 126.07
# Eval num_timesteps=120000, episode_reward=49.18 +/- 16.93
# Episode length: 135.00 +/- 127.24
# Eval num_timesteps=130000, episode_reward=37.53 +/- 27.05
# Episode length: 225.20 +/- 185.65
# Eval num_timesteps=140000, episode_reward=43.12 +/- 23.11
# Episode length: 204.40 +/- 162.11
# Eval num_timesteps=150000, episode_reward=54.63 +/- 1.64
# Episode length: 102.00 +/- 51.82
# Eval num_timesteps=160000, episode_reward=54.94 +/- 2.23
# Episode length: 104.10 +/- 40.26
# Eval num_timesteps=170000, episode_reward=55.10 +/- 2.01
# Episode length: 109.20 +/- 41.40
# Eval num_timesteps=180000, episode_reward=49.89 +/- 17.75
# Episode length: 146.70 +/- 120.85
# Eval num_timesteps=190000, episode_reward=48.71 +/- 17.74
# Episode length: 130.70 +/- 128.62
# Eval num_timesteps=200000, episode_reward=49.74 +/- 16.69
# Episode length: 149.50 +/- 132.33
#   [A_baseline] seed 3: done
# Eval num_timesteps=10000, episode_reward=-5.09 +/- 0.71
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=36.87 +/- 26.42
# Episode length: 223.00 +/- 182.81
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=30.88 +/- 28.83
# Episode length: 248.30 +/- 206.72
# Eval num_timesteps=40000, episode_reward=32.01 +/- 27.53
# Episode length: 264.90 +/- 195.50
# Eval num_timesteps=50000, episode_reward=32.72 +/- 27.06
# Episode length: 275.80 +/- 195.14
# Eval num_timesteps=60000, episode_reward=31.26 +/- 28.54
# Episode length: 271.70 +/- 200.99
# Eval num_timesteps=70000, episode_reward=41.99 +/- 22.32
# Episode length: 150.90 +/- 175.90
# New best mean reward!
# Eval num_timesteps=80000, episode_reward=37.19 +/- 27.36
# Episode length: 211.90 +/- 191.22
# Eval num_timesteps=90000, episode_reward=38.01 +/- 25.77
# Episode length: 233.20 +/- 184.01
# Eval num_timesteps=100000, episode_reward=55.80 +/- 1.50
# Episode length: 111.70 +/- 35.93
# New best mean reward!
# Eval num_timesteps=110000, episode_reward=54.92 +/- 1.83
# Episode length: 116.10 +/- 33.99
# Eval num_timesteps=120000, episode_reward=38.08 +/- 26.40
# Episode length: 224.30 +/- 183.75
# Eval num_timesteps=130000, episode_reward=37.72 +/- 26.94
# Episode length: 233.80 +/- 183.24
# Eval num_timesteps=140000, episode_reward=55.10 +/- 2.43
# Episode length: 115.60 +/- 56.71
# Eval num_timesteps=150000, episode_reward=55.24 +/- 2.96
# Episode length: 99.80 +/- 54.06
# Eval num_timesteps=160000, episode_reward=49.17 +/- 18.04
# Episode length: 139.70 +/- 128.87
# Eval num_timesteps=170000, episode_reward=49.61 +/- 16.56
# Episode length: 140.90 +/- 129.74
# Eval num_timesteps=180000, episode_reward=55.97 +/- 2.71
# Episode length: 117.40 +/- 65.28
# New best mean reward!
# Eval num_timesteps=190000, episode_reward=54.88 +/- 2.18
# Episode length: 80.40 +/- 36.50
# Eval num_timesteps=200000, episode_reward=55.33 +/- 1.52
# Episode length: 135.10 +/- 64.82
#   [A_baseline] seed 4: done
# Eval num_timesteps=10000, episode_reward=-5.69 +/- 1.45
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=25.22 +/- 29.15
# Episode length: 304.70 +/- 197.55
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=42.17 +/- 22.69
# Episode length: 181.70 +/- 167.62
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=23.93 +/- 29.29
# Episode length: 313.60 +/- 192.76
# Eval num_timesteps=50000, episode_reward=47.76 +/- 18.07
# Episode length: 133.90 +/- 130.14
# New best mean reward!
# Eval num_timesteps=60000, episode_reward=26.08 +/- 29.20
# Episode length: 311.40 +/- 191.70
# Eval num_timesteps=70000, episode_reward=27.86 +/- 29.96
# Episode length: 338.30 +/- 170.49
# Eval num_timesteps=80000, episode_reward=15.38 +/- 25.99
# Episode length: 373.60 +/- 193.28
# Eval num_timesteps=90000, episode_reward=25.91 +/- 28.51
# Episode length: 311.60 +/- 193.42
# Eval num_timesteps=100000, episode_reward=43.72 +/- 22.19
# Episode length: 175.00 +/- 165.89
# Eval num_timesteps=110000, episode_reward=31.77 +/- 29.01
# Episode length: 258.40 +/- 198.87
# Eval num_timesteps=120000, episode_reward=43.38 +/- 23.76
# Episode length: 191.20 +/- 156.82
# Eval num_timesteps=130000, episode_reward=42.47 +/- 22.56
# Episode length: 157.10 +/- 174.13
# Eval num_timesteps=140000, episode_reward=43.64 +/- 23.19
# Episode length: 193.20 +/- 158.42
# Eval num_timesteps=150000, episode_reward=32.07 +/- 28.12
# Episode length: 267.90 +/- 194.05
# Eval num_timesteps=160000, episode_reward=48.83 +/- 15.61
# Episode length: 119.80 +/- 132.95
# New best mean reward!
# Eval num_timesteps=170000, episode_reward=49.40 +/- 18.04
# Episode length: 147.80 +/- 124.83
# New best mean reward!
# Eval num_timesteps=180000, episode_reward=37.87 +/- 27.14
# Episode length: 223.10 +/- 186.71
# Eval num_timesteps=190000, episode_reward=50.84 +/- 17.24
# Episode length: 167.80 +/- 113.94
# New best mean reward!
# Eval num_timesteps=200000, episode_reward=48.54 +/- 16.18
# Episode length: 121.40 +/- 129.89
#   [A_baseline] seed 5: done
# Eval num_timesteps=10000, episode_reward=-4.98 +/- 1.01
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=36.12 +/- 28.24
# Episode length: 233.60 +/- 180.73
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=19.06 +/- 26.81
# Episode length: 331.20 +/- 208.32
# Eval num_timesteps=40000, episode_reward=18.88 +/- 28.97
# Episode length: 357.10 +/- 189.05
# Eval num_timesteps=50000, episode_reward=32.42 +/- 27.66
# Episode length: 283.10 +/- 181.56
# Eval num_timesteps=60000, episode_reward=20.03 +/- 27.45
# Episode length: 338.70 +/- 203.05
# Eval num_timesteps=70000, episode_reward=42.20 +/- 22.89
# Episode length: 163.20 +/- 170.51
# New best mean reward!
# Eval num_timesteps=80000, episode_reward=19.07 +/- 28.51
# Episode length: 334.70 +/- 203.79
# Eval num_timesteps=90000, episode_reward=48.92 +/- 17.14
# Episode length: 178.20 +/- 135.64
# New best mean reward!
# Eval num_timesteps=100000, episode_reward=36.69 +/- 25.46
# Episode length: 238.20 +/- 181.56
# Eval num_timesteps=110000, episode_reward=36.57 +/- 25.40
# Episode length: 206.10 +/- 195.51
# Eval num_timesteps=120000, episode_reward=49.26 +/- 18.08
# Episode length: 155.80 +/- 120.00
# New best mean reward!
# Eval num_timesteps=130000, episode_reward=43.65 +/- 22.80
# Episode length: 192.10 +/- 161.25
# Eval num_timesteps=140000, episode_reward=43.87 +/- 23.13
# Episode length: 187.80 +/- 160.90
# Eval num_timesteps=150000, episode_reward=48.78 +/- 17.41
# Episode length: 137.70 +/- 126.81
# Eval num_timesteps=160000, episode_reward=36.03 +/- 27.14
# Episode length: 201.80 +/- 197.03
# Eval num_timesteps=170000, episode_reward=49.92 +/- 16.15
# Episode length: 149.60 +/- 123.26
# New best mean reward!
# Eval num_timesteps=180000, episode_reward=50.48 +/- 18.67
# Episode length: 156.10 +/- 117.73
# New best mean reward!
# Eval num_timesteps=190000, episode_reward=55.21 +/- 2.53
# Episode length: 102.90 +/- 44.07
# New best mean reward!
# Eval num_timesteps=200000, episode_reward=49.72 +/- 17.43
# Episode length: 139.50 +/- 128.11
#   [A_baseline] seed 6: done
# Eval num_timesteps=10000, episode_reward=-5.16 +/- 0.99
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=37.16 +/- 26.10
# Episode length: 253.40 +/- 200.71
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=12.89 +/- 25.77
# Episode length: 371.00 +/- 198.27
# Eval num_timesteps=40000, episode_reward=30.94 +/- 27.34
# Episode length: 252.90 +/- 203.23
# Eval num_timesteps=50000, episode_reward=20.53 +/- 28.53
# Episode length: 368.70 +/- 168.57
# Eval num_timesteps=60000, episode_reward=31.43 +/- 28.55
# Episode length: 247.10 +/- 207.23
# Eval num_timesteps=70000, episode_reward=43.43 +/- 23.70
# Episode length: 196.70 +/- 175.69
# New best mean reward!
# Eval num_timesteps=80000, episode_reward=43.56 +/- 23.79
# Episode length: 188.20 +/- 160.55
# New best mean reward!
# Eval num_timesteps=90000, episode_reward=25.29 +/- 29.55
# Episode length: 321.30 +/- 208.40
# Eval num_timesteps=100000, episode_reward=54.79 +/- 1.89
# Episode length: 105.40 +/- 40.56
# New best mean reward!
# Eval num_timesteps=110000, episode_reward=43.38 +/- 22.97
# Episode length: 169.10 +/- 168.08
# Eval num_timesteps=120000, episode_reward=48.80 +/- 17.89
# Episode length: 140.30 +/- 126.50
# Eval num_timesteps=130000, episode_reward=37.42 +/- 25.08
# Episode length: 201.40 +/- 196.88
# Eval num_timesteps=140000, episode_reward=48.99 +/- 17.95
# Episode length: 146.20 +/- 124.65
# Eval num_timesteps=150000, episode_reward=49.55 +/- 18.18
# Episode length: 155.00 +/- 124.65
# Eval num_timesteps=160000, episode_reward=43.84 +/- 22.95
# Episode length: 190.80 +/- 163.75
# Eval num_timesteps=170000, episode_reward=42.66 +/- 24.30
# Episode length: 162.20 +/- 170.22
# Eval num_timesteps=180000, episode_reward=36.20 +/- 27.35
# Episode length: 216.10 +/- 188.63
# Eval num_timesteps=190000, episode_reward=53.99 +/- 1.38
# Episode length: 71.90 +/- 26.28
# Eval num_timesteps=200000, episode_reward=54.36 +/- 2.13
# Episode length: 96.60 +/- 38.36
#   [A_baseline] seed 7: done
# Eval num_timesteps=10000, episode_reward=-4.63 +/- 0.91
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=13.90 +/- 25.40
# Episode length: 370.90 +/- 197.84
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=25.87 +/- 29.55
# Episode length: 295.40 +/- 205.99
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=25.78 +/- 27.61
# Episode length: 288.10 +/- 214.11
# Eval num_timesteps=50000, episode_reward=19.96 +/- 28.24
# Episode length: 329.00 +/- 210.45
# Eval num_timesteps=60000, episode_reward=25.51 +/- 29.80
# Episode length: 304.00 +/- 199.90
# Eval num_timesteps=70000, episode_reward=37.60 +/- 28.23
# Episode length: 230.90 +/- 179.76
# New best mean reward!
# Eval num_timesteps=80000, episode_reward=44.08 +/- 23.73
# Episode length: 216.50 +/- 146.37
# New best mean reward!
# Eval num_timesteps=90000, episode_reward=19.83 +/- 27.83
# Episode length: 328.70 +/- 210.43
# Eval num_timesteps=100000, episode_reward=43.39 +/- 21.62
# Episode length: 178.40 +/- 167.81
# Eval num_timesteps=110000, episode_reward=48.45 +/- 17.76
# Episode length: 129.50 +/- 131.91
# New best mean reward!
# Eval num_timesteps=120000, episode_reward=42.84 +/- 23.37
# Episode length: 185.10 +/- 164.15
# Eval num_timesteps=130000, episode_reward=38.04 +/- 25.60
# Episode length: 240.30 +/- 177.46
# Eval num_timesteps=140000, episode_reward=38.29 +/- 26.74
# Episode length: 229.80 +/- 181.54
# Eval num_timesteps=150000, episode_reward=48.58 +/- 17.41
# Episode length: 145.90 +/- 144.20
# New best mean reward!
# Eval num_timesteps=160000, episode_reward=50.77 +/- 18.44
# Episode length: 167.90 +/- 122.63
# New best mean reward!
# Eval num_timesteps=170000, episode_reward=42.03 +/- 23.34
# Episode length: 161.50 +/- 175.93
# Eval num_timesteps=180000, episode_reward=55.70 +/- 1.84
# Episode length: 106.50 +/- 21.64
# New best mean reward!
# Eval num_timesteps=190000, episode_reward=42.53 +/- 23.17
# Episode length: 157.20 +/- 172.73
# Eval num_timesteps=200000, episode_reward=55.21 +/- 2.48
# Episode length: 92.40 +/- 43.04
#   [A_baseline] seed 8: done
# Eval num_timesteps=10000, episode_reward=-9.02 +/- 1.31
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=20.05 +/- 28.17
# Episode length: 365.70 +/- 166.25
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=25.55 +/- 28.74
# Episode length: 301.60 +/- 198.99
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=37.16 +/- 25.18
# Episode length: 234.10 +/- 186.25
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=42.83 +/- 23.55
# Episode length: 213.40 +/- 172.11
# New best mean reward!
# Eval num_timesteps=60000, episode_reward=37.55 +/- 25.54
# Episode length: 253.00 +/- 185.73
# Eval num_timesteps=70000, episode_reward=25.52 +/- 28.95
# Episode length: 308.00 +/- 200.72
# Eval num_timesteps=80000, episode_reward=53.57 +/- 1.80
# Episode length: 86.40 +/- 46.38
# New best mean reward!
# Eval num_timesteps=90000, episode_reward=25.75 +/- 29.02
# Episode length: 314.70 +/- 190.09
# Eval num_timesteps=100000, episode_reward=42.45 +/- 24.17
# Episode length: 183.50 +/- 169.41
# Eval num_timesteps=110000, episode_reward=48.60 +/- 16.33
# Episode length: 126.40 +/- 128.74
# Eval num_timesteps=120000, episode_reward=49.34 +/- 16.45
# Episode length: 133.10 +/- 127.64
# Eval num_timesteps=130000, episode_reward=42.00 +/- 23.32
# Episode length: 157.40 +/- 172.86
# Eval num_timesteps=140000, episode_reward=54.49 +/- 2.37
# Episode length: 98.20 +/- 50.77
# New best mean reward!
# Eval num_timesteps=150000, episode_reward=36.77 +/- 25.75
# Episode length: 198.50 +/- 200.44
# Eval num_timesteps=160000, episode_reward=54.90 +/- 2.69
# Episode length: 108.10 +/- 68.80
# New best mean reward!
# Eval num_timesteps=170000, episode_reward=53.61 +/- 1.63
# Episode length: 66.70 +/- 28.47
# Eval num_timesteps=180000, episode_reward=55.43 +/- 2.22
# Episode length: 106.30 +/- 44.63
# New best mean reward!
# Eval num_timesteps=190000, episode_reward=37.60 +/- 27.41
# Episode length: 221.50 +/- 185.98
# Eval num_timesteps=200000, episode_reward=50.06 +/- 18.26
# Episode length: 166.00 +/- 130.43
#   [A_baseline] seed 9: done
#
# --- Konfiguracja B_wysoki_lr ---
# Eval num_timesteps=10000, episode_reward=-5.48 +/- 0.71
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=19.46 +/- 28.21
# Episode length: 338.10 +/- 204.22
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=25.61 +/- 27.47
# Episode length: 311.00 +/- 197.86
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=30.24 +/- 28.80
# Episode length: 277.50 +/- 196.34
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=20.22 +/- 29.42
# Episode length: 353.30 +/- 182.23
# Eval num_timesteps=60000, episode_reward=30.87 +/- 28.79
# Episode length: 270.80 +/- 194.53
# New best mean reward!
# Eval num_timesteps=70000, episode_reward=36.86 +/- 25.89
# Episode length: 219.80 +/- 187.67
# New best mean reward!
# Eval num_timesteps=80000, episode_reward=25.34 +/- 29.59
# Episode length: 318.20 +/- 185.23
# Eval num_timesteps=90000, episode_reward=42.25 +/- 23.76
# Episode length: 177.90 +/- 163.43
# New best mean reward!
# Eval num_timesteps=100000, episode_reward=24.46 +/- 29.49
# Episode length: 299.70 +/- 201.32
# Eval num_timesteps=110000, episode_reward=43.72 +/- 23.38
# Episode length: 230.40 +/- 149.11
# New best mean reward!
# Eval num_timesteps=120000, episode_reward=54.80 +/- 1.60
# Episode length: 96.80 +/- 36.38
# New best mean reward!
# Eval num_timesteps=130000, episode_reward=48.27 +/- 17.65
# Episode length: 160.20 +/- 154.52
# Eval num_timesteps=140000, episode_reward=48.24 +/- 17.36
# Episode length: 131.50 +/- 126.07
# Eval num_timesteps=150000, episode_reward=49.29 +/- 17.73
# Episode length: 140.50 +/- 128.48
# Eval num_timesteps=160000, episode_reward=36.96 +/- 26.19
# Episode length: 214.90 +/- 191.49
# Eval num_timesteps=170000, episode_reward=49.26 +/- 17.46
# Episode length: 140.30 +/- 123.89
# Eval num_timesteps=180000, episode_reward=43.52 +/- 24.09
# Episode length: 179.00 +/- 162.56
# Eval num_timesteps=190000, episode_reward=50.66 +/- 18.36
# Episode length: 157.20 +/- 119.10
# Eval num_timesteps=200000, episode_reward=54.89 +/- 2.96
# Episode length: 84.80 +/- 50.60
# New best mean reward!
#   [B_wysoki_lr] seed 0: done
# Eval num_timesteps=10000, episode_reward=-5.39 +/- 0.77
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=32.46 +/- 27.49
# Episode length: 250.10 +/- 206.43
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=54.03 +/- 2.28
# Episode length: 83.90 +/- 50.22
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=31.57 +/- 28.11
# Episode length: 268.30 +/- 195.74
# Eval num_timesteps=50000, episode_reward=32.05 +/- 28.64
# Episode length: 297.00 +/- 166.93
# Eval num_timesteps=60000, episode_reward=43.23 +/- 21.88
# Episode length: 169.40 +/- 171.45
# Eval num_timesteps=70000, episode_reward=38.16 +/- 26.62
# Episode length: 220.10 +/- 185.46
# Eval num_timesteps=80000, episode_reward=49.33 +/- 17.02
# Episode length: 158.20 +/- 133.38
# Eval num_timesteps=90000, episode_reward=43.83 +/- 22.30
# Episode length: 183.90 +/- 162.14
# Eval num_timesteps=100000, episode_reward=27.74 +/- 27.41
# Episode length: 314.40 +/- 192.70
# Eval num_timesteps=110000, episode_reward=43.71 +/- 23.05
# Episode length: 210.60 +/- 158.57
# Eval num_timesteps=120000, episode_reward=49.30 +/- 17.98
# Episode length: 150.80 +/- 124.75
# Eval num_timesteps=130000, episode_reward=54.51 +/- 1.98
# Episode length: 87.60 +/- 38.21
# New best mean reward!
# Eval num_timesteps=140000, episode_reward=43.59 +/- 22.08
# Episode length: 163.10 +/- 173.43
# Eval num_timesteps=150000, episode_reward=48.90 +/- 17.90
# Episode length: 125.90 +/- 127.18
# Eval num_timesteps=160000, episode_reward=49.68 +/- 18.11
# Episode length: 139.20 +/- 124.62
# Eval num_timesteps=170000, episode_reward=55.69 +/- 2.82
# Episode length: 109.60 +/- 66.18
# New best mean reward!
# Eval num_timesteps=180000, episode_reward=54.50 +/- 1.45
# Episode length: 80.10 +/- 27.76
# Eval num_timesteps=190000, episode_reward=55.38 +/- 2.24
# Episode length: 90.70 +/- 38.10
# Eval num_timesteps=200000, episode_reward=53.88 +/- 1.16
# Episode length: 70.20 +/- 36.33
#   [B_wysoki_lr] seed 1: done
# Eval num_timesteps=10000, episode_reward=-5.25 +/- 1.95
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=43.37 +/- 22.30
# Episode length: 171.50 +/- 167.22
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=30.88 +/- 28.71
# Episode length: 258.70 +/- 202.02
# Eval num_timesteps=40000, episode_reward=43.29 +/- 23.19
# Episode length: 170.70 +/- 168.78
# Eval num_timesteps=50000, episode_reward=43.64 +/- 23.29
# Episode length: 171.60 +/- 167.34
# New best mean reward!
# Eval num_timesteps=60000, episode_reward=44.08 +/- 23.66
# Episode length: 209.50 +/- 151.59
# New best mean reward!
# Eval num_timesteps=70000, episode_reward=41.89 +/- 22.24
# Episode length: 159.00 +/- 175.60
# Eval num_timesteps=80000, episode_reward=49.40 +/- 17.82
# Episode length: 141.30 +/- 133.79
# New best mean reward!
# Eval num_timesteps=90000, episode_reward=54.75 +/- 0.78
# Episode length: 88.10 +/- 17.65
# New best mean reward!
# Eval num_timesteps=100000, episode_reward=44.89 +/- 22.91
# Episode length: 186.70 +/- 159.29
# Eval num_timesteps=110000, episode_reward=54.40 +/- 2.48
# Episode length: 90.70 +/- 44.61
# Eval num_timesteps=120000, episode_reward=44.19 +/- 24.25
# Episode length: 203.70 +/- 159.13
# Eval num_timesteps=130000, episode_reward=49.51 +/- 17.34
# Episode length: 144.90 +/- 123.00
# Eval num_timesteps=140000, episode_reward=49.42 +/- 17.49
# Episode length: 140.60 +/- 126.36
# Eval num_timesteps=150000, episode_reward=55.77 +/- 2.55
# Episode length: 122.10 +/- 44.63
# New best mean reward!
# Eval num_timesteps=160000, episode_reward=53.38 +/- 1.51
# Episode length: 69.70 +/- 22.23
# Eval num_timesteps=170000, episode_reward=42.27 +/- 24.32
# Episode length: 155.60 +/- 173.98
# Eval num_timesteps=180000, episode_reward=54.23 +/- 1.72
# Episode length: 88.60 +/- 37.47
# Eval num_timesteps=190000, episode_reward=55.51 +/- 3.09
# Episode length: 109.50 +/- 62.20
# Eval num_timesteps=200000, episode_reward=55.62 +/- 2.56
# Episode length: 95.30 +/- 53.00
#   [B_wysoki_lr] seed 2: done
# Eval num_timesteps=10000, episode_reward=-4.44 +/- 1.85
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=32.02 +/- 27.30
# Episode length: 240.90 +/- 212.27
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=30.74 +/- 27.97
# Episode length: 252.70 +/- 205.74
# Eval num_timesteps=40000, episode_reward=32.63 +/- 26.85
# Episode length: 269.70 +/- 190.43
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=31.92 +/- 28.47
# Episode length: 264.50 +/- 195.92
# Eval num_timesteps=60000, episode_reward=38.78 +/- 25.56
# Episode length: 239.10 +/- 175.74
# New best mean reward!
# Eval num_timesteps=70000, episode_reward=32.50 +/- 27.17
# Episode length: 268.20 +/- 201.73
# Eval num_timesteps=80000, episode_reward=36.15 +/- 26.80
# Episode length: 204.80 +/- 194.74
# Eval num_timesteps=90000, episode_reward=32.01 +/- 27.51
# Episode length: 256.00 +/- 200.97
# Eval num_timesteps=100000, episode_reward=53.75 +/- 2.04
# Episode length: 84.50 +/- 48.22
# New best mean reward!
# Eval num_timesteps=110000, episode_reward=43.45 +/- 23.31
# Episode length: 188.90 +/- 167.07
# Eval num_timesteps=120000, episode_reward=49.62 +/- 18.04
# Episode length: 182.80 +/- 120.42
# Eval num_timesteps=130000, episode_reward=49.98 +/- 16.70
# Episode length: 150.00 +/- 122.74
# Eval num_timesteps=140000, episode_reward=55.48 +/- 1.96
# Episode length: 98.40 +/- 39.09
# New best mean reward!
# Eval num_timesteps=150000, episode_reward=43.85 +/- 24.71
# Episode length: 204.90 +/- 160.47
# Eval num_timesteps=160000, episode_reward=54.74 +/- 2.66
# Episode length: 103.80 +/- 56.29
# Eval num_timesteps=170000, episode_reward=54.55 +/- 2.69
# Episode length: 86.10 +/- 41.14
# Eval num_timesteps=180000, episode_reward=54.98 +/- 2.26
# Episode length: 86.20 +/- 31.53
# Eval num_timesteps=190000, episode_reward=54.71 +/- 1.29
# Episode length: 73.70 +/- 20.87
# Eval num_timesteps=200000, episode_reward=48.84 +/- 18.05
# Episode length: 133.20 +/- 129.42
#   [B_wysoki_lr] seed 3: done
# Eval num_timesteps=10000, episode_reward=-4.84 +/- 0.74
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=42.22 +/- 23.04
# Episode length: 166.50 +/- 171.02
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=42.97 +/- 23.13
# Episode length: 203.10 +/- 161.24
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=37.80 +/- 25.58
# Episode length: 233.80 +/- 184.41
# Eval num_timesteps=50000, episode_reward=13.76 +/- 25.81
# Episode length: 373.40 +/- 193.54
# Eval num_timesteps=60000, episode_reward=44.71 +/- 22.68
# Episode length: 207.70 +/- 152.18
# New best mean reward!
# Eval num_timesteps=70000, episode_reward=37.40 +/- 26.35
# Episode length: 209.60 +/- 192.70
# Eval num_timesteps=80000, episode_reward=49.69 +/- 15.79
# Episode length: 129.70 +/- 130.18
# New best mean reward!
# Eval num_timesteps=90000, episode_reward=31.88 +/- 29.39
# Episode length: 255.90 +/- 202.11
# Eval num_timesteps=100000, episode_reward=54.36 +/- 1.82
# Episode length: 92.50 +/- 46.62
# New best mean reward!
# Eval num_timesteps=110000, episode_reward=37.01 +/- 26.73
# Episode length: 200.60 +/- 199.07
# Eval num_timesteps=120000, episode_reward=49.39 +/- 16.80
# Episode length: 128.10 +/- 128.64
# Eval num_timesteps=130000, episode_reward=49.92 +/- 16.40
# Episode length: 136.20 +/- 126.10
# Eval num_timesteps=140000, episode_reward=41.72 +/- 22.63
# Episode length: 151.60 +/- 176.64
# Eval num_timesteps=150000, episode_reward=56.09 +/- 3.04
# Episode length: 109.60 +/- 38.60
# New best mean reward!
# Eval num_timesteps=160000, episode_reward=55.74 +/- 1.99
# Episode length: 96.40 +/- 34.53
# Eval num_timesteps=170000, episode_reward=55.16 +/- 2.21
# Episode length: 85.50 +/- 40.52
# Eval num_timesteps=180000, episode_reward=56.52 +/- 2.24
# Episode length: 105.50 +/- 36.38
# New best mean reward!
# Eval num_timesteps=190000, episode_reward=55.24 +/- 2.36
# Episode length: 87.30 +/- 33.17
# Eval num_timesteps=200000, episode_reward=50.99 +/- 18.57
# Episode length: 144.70 +/- 120.07
#   [B_wysoki_lr] seed 4: done
# Eval num_timesteps=10000, episode_reward=-5.74 +/- 1.16
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=30.87 +/- 28.65
# Episode length: 277.00 +/- 195.63
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=42.09 +/- 22.58
# Episode length: 165.40 +/- 171.84
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=31.74 +/- 28.61
# Episode length: 266.30 +/- 194.11
# Eval num_timesteps=50000, episode_reward=43.21 +/- 24.17
# Episode length: 215.50 +/- 147.69
# New best mean reward!
# Eval num_timesteps=60000, episode_reward=42.21 +/- 22.61
# Episode length: 190.50 +/- 170.98
# Eval num_timesteps=70000, episode_reward=43.66 +/- 23.32
# Episode length: 209.30 +/- 156.38
# New best mean reward!
# Eval num_timesteps=80000, episode_reward=31.58 +/- 28.64
# Episode length: 274.10 +/- 194.96
# Eval num_timesteps=90000, episode_reward=36.10 +/- 26.44
# Episode length: 193.80 +/- 201.59
# Eval num_timesteps=100000, episode_reward=54.88 +/- 2.10
# Episode length: 110.10 +/- 60.96
# New best mean reward!
# Eval num_timesteps=110000, episode_reward=49.35 +/- 16.35
# Episode length: 123.30 +/- 129.45
# Eval num_timesteps=120000, episode_reward=49.15 +/- 16.91
# Episode length: 133.50 +/- 132.08
# Eval num_timesteps=130000, episode_reward=54.27 +/- 2.50
# Episode length: 87.80 +/- 57.60
# Eval num_timesteps=140000, episode_reward=49.16 +/- 16.64
# Episode length: 125.40 +/- 128.15
# Eval num_timesteps=150000, episode_reward=54.39 +/- 2.72
# Episode length: 82.70 +/- 47.93
# Eval num_timesteps=160000, episode_reward=55.54 +/- 1.76
# Episode length: 103.70 +/- 35.95
# New best mean reward!
# Eval num_timesteps=170000, episode_reward=48.91 +/- 18.25
# Episode length: 131.70 +/- 129.87
# Eval num_timesteps=180000, episode_reward=55.63 +/- 2.08
# Episode length: 93.40 +/- 36.77
# New best mean reward!
# Eval num_timesteps=190000, episode_reward=54.91 +/- 2.43
# Episode length: 81.30 +/- 44.18
# Eval num_timesteps=200000, episode_reward=55.38 +/- 2.32
# Episode length: 94.40 +/- 33.55
#   [B_wysoki_lr] seed 5: done
# Eval num_timesteps=10000, episode_reward=-5.58 +/- 0.86
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=37.50 +/- 28.18
# Episode length: 226.50 +/- 182.18
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=21.20 +/- 29.48
# Episode length: 351.70 +/- 186.20
# Eval num_timesteps=40000, episode_reward=10.03 +/- 22.20
# Episode length: 421.90 +/- 157.10
# Eval num_timesteps=50000, episode_reward=31.20 +/- 27.10
# Episode length: 237.40 +/- 217.08
# Eval num_timesteps=60000, episode_reward=48.51 +/- 17.00
# Episode length: 129.10 +/- 129.87
# New best mean reward!
# Eval num_timesteps=70000, episode_reward=27.31 +/- 28.82
# Episode length: 309.90 +/- 192.65
# Eval num_timesteps=80000, episode_reward=43.04 +/- 23.66
# Episode length: 231.30 +/- 181.24
# Eval num_timesteps=90000, episode_reward=55.20 +/- 2.07
# Episode length: 100.10 +/- 44.75
# New best mean reward!
# Eval num_timesteps=100000, episode_reward=54.65 +/- 1.86
# Episode length: 96.60 +/- 48.38
# Eval num_timesteps=110000, episode_reward=50.34 +/- 18.09
# Episode length: 153.10 +/- 120.13
# Eval num_timesteps=120000, episode_reward=54.92 +/- 2.55
# Episode length: 123.10 +/- 88.42
# Eval num_timesteps=130000, episode_reward=50.40 +/- 18.73
# Episode length: 170.20 +/- 122.12
# Eval num_timesteps=140000, episode_reward=50.28 +/- 17.93
# Episode length: 160.50 +/- 121.08
# Eval num_timesteps=150000, episode_reward=55.46 +/- 2.29
# Episode length: 108.10 +/- 55.75
# New best mean reward!
# Eval num_timesteps=160000, episode_reward=49.41 +/- 18.27
# Episode length: 174.50 +/- 129.30
# Eval num_timesteps=170000, episode_reward=49.12 +/- 16.40
# Episode length: 172.90 +/- 140.79
# Eval num_timesteps=180000, episode_reward=56.19 +/- 2.08
# Episode length: 100.50 +/- 33.52
# New best mean reward!
# Eval num_timesteps=190000, episode_reward=55.03 +/- 2.90
# Episode length: 99.00 +/- 43.55
# Eval num_timesteps=200000, episode_reward=56.01 +/- 1.51
# Episode length: 126.30 +/- 48.98
#   [B_wysoki_lr] seed 6: done
# Eval num_timesteps=10000, episode_reward=-5.08 +/- 1.08
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=42.77 +/- 23.43
# Episode length: 223.00 +/- 186.18
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=44.20 +/- 21.54
# Episode length: 181.70 +/- 167.74
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=49.10 +/- 17.69
# Episode length: 128.20 +/- 127.12
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=44.07 +/- 21.79
# Episode length: 174.40 +/- 165.15
# Eval num_timesteps=60000, episode_reward=36.99 +/- 26.26
# Episode length: 222.90 +/- 186.29
# Eval num_timesteps=70000, episode_reward=49.86 +/- 16.62
# Episode length: 155.40 +/- 119.38
# New best mean reward!
# Eval num_timesteps=80000, episode_reward=48.74 +/- 16.43
# Episode length: 118.50 +/- 131.32
# Eval num_timesteps=90000, episode_reward=48.61 +/- 17.66
# Episode length: 126.70 +/- 133.54
# Eval num_timesteps=100000, episode_reward=47.73 +/- 18.22
# Episode length: 116.50 +/- 132.32
# Eval num_timesteps=110000, episode_reward=49.67 +/- 17.79
# Episode length: 145.20 +/- 123.09
# Eval num_timesteps=120000, episode_reward=42.82 +/- 24.09
# Episode length: 176.80 +/- 167.35
# Eval num_timesteps=130000, episode_reward=55.15 +/- 2.08
# Episode length: 88.10 +/- 36.36
# New best mean reward!
# Eval num_timesteps=140000, episode_reward=49.96 +/- 18.22
# Episode length: 145.40 +/- 127.92
# Eval num_timesteps=150000, episode_reward=54.97 +/- 2.45
# Episode length: 80.80 +/- 32.86
# Eval num_timesteps=160000, episode_reward=54.82 +/- 1.95
# Episode length: 89.80 +/- 24.25
# Eval num_timesteps=170000, episode_reward=55.70 +/- 2.17
# Episode length: 104.10 +/- 34.96
# New best mean reward!
# Eval num_timesteps=180000, episode_reward=55.22 +/- 1.69
# Episode length: 102.70 +/- 39.95
# Eval num_timesteps=190000, episode_reward=54.73 +/- 1.92
# Episode length: 79.70 +/- 29.19
# Eval num_timesteps=200000, episode_reward=55.89 +/- 2.23
# Episode length: 104.00 +/- 39.21
# New best mean reward!
#   [B_wysoki_lr] seed 7: done
# Eval num_timesteps=10000, episode_reward=-5.13 +/- 1.54
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=26.84 +/- 29.35
# Episode length: 307.00 +/- 195.51
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=20.88 +/- 27.25
# Episode length: 337.40 +/- 199.82
# Eval num_timesteps=40000, episode_reward=37.25 +/- 25.92
# Episode length: 209.60 +/- 193.44
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=24.93 +/- 28.58
# Episode length: 283.10 +/- 218.51
# Eval num_timesteps=60000, episode_reward=31.70 +/- 27.18
# Episode length: 251.40 +/- 204.70
# Eval num_timesteps=70000, episode_reward=31.79 +/- 28.06
# Episode length: 307.90 +/- 167.96
# Eval num_timesteps=80000, episode_reward=55.63 +/- 1.45
# Episode length: 132.90 +/- 64.49
# New best mean reward!
# Eval num_timesteps=90000, episode_reward=49.23 +/- 16.64
# Episode length: 138.40 +/- 137.70
# Eval num_timesteps=100000, episode_reward=49.35 +/- 18.12
# Episode length: 142.50 +/- 126.55
# Eval num_timesteps=110000, episode_reward=49.48 +/- 18.33
# Episode length: 142.60 +/- 125.01
# Eval num_timesteps=120000, episode_reward=43.08 +/- 23.18
# Episode length: 185.10 +/- 168.16
# Eval num_timesteps=130000, episode_reward=54.95 +/- 1.74
# Episode length: 92.40 +/- 35.45
# Eval num_timesteps=140000, episode_reward=54.64 +/- 1.64
# Episode length: 95.80 +/- 43.07
# Eval num_timesteps=150000, episode_reward=49.40 +/- 18.64
# Episode length: 136.70 +/- 125.65
# Eval num_timesteps=160000, episode_reward=49.63 +/- 17.69
# Episode length: 145.00 +/- 123.86
# Eval num_timesteps=170000, episode_reward=55.15 +/- 2.40
# Episode length: 95.60 +/- 44.82
# Eval num_timesteps=180000, episode_reward=48.96 +/- 17.98
# Episode length: 133.00 +/- 128.48
# Eval num_timesteps=190000, episode_reward=56.63 +/- 2.41
# Episode length: 120.10 +/- 52.70
# New best mean reward!
# Eval num_timesteps=200000, episode_reward=55.83 +/- 2.05
# Episode length: 100.90 +/- 38.41
#   [B_wysoki_lr] seed 8: done
# Eval num_timesteps=10000, episode_reward=-6.25 +/- 1.20
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=31.60 +/- 28.72
# Episode length: 343.10 +/- 174.61
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=20.14 +/- 28.18
# Episode length: 341.90 +/- 196.74
# Eval num_timesteps=40000, episode_reward=31.25 +/- 28.43
# Episode length: 270.70 +/- 189.85
# Eval num_timesteps=50000, episode_reward=20.50 +/- 28.62
# Episode length: 344.30 +/- 190.91
# Eval num_timesteps=60000, episode_reward=42.41 +/- 23.90
# Episode length: 185.70 +/- 171.84
# New best mean reward!
# Eval num_timesteps=70000, episode_reward=43.05 +/- 24.28
# Episode length: 235.70 +/- 165.55
# New best mean reward!
# Eval num_timesteps=80000, episode_reward=43.56 +/- 22.81
# Episode length: 168.70 +/- 169.93
# New best mean reward!
# Eval num_timesteps=90000, episode_reward=42.34 +/- 22.95
# Episode length: 169.20 +/- 172.35
# Eval num_timesteps=100000, episode_reward=54.37 +/- 1.86
# Episode length: 125.30 +/- 94.09
# New best mean reward!
# Eval num_timesteps=110000, episode_reward=43.52 +/- 22.44
# Episode length: 195.50 +/- 163.91
# Eval num_timesteps=120000, episode_reward=43.22 +/- 23.98
# Episode length: 180.20 +/- 162.20
# Eval num_timesteps=130000, episode_reward=42.19 +/- 23.62
# Episode length: 160.30 +/- 173.45
# Eval num_timesteps=140000, episode_reward=36.80 +/- 26.53
# Episode length: 203.70 +/- 196.55
# Eval num_timesteps=150000, episode_reward=38.54 +/- 26.32
# Episode length: 218.10 +/- 187.50
# Eval num_timesteps=160000, episode_reward=56.17 +/- 1.52
# Episode length: 118.20 +/- 55.88
# New best mean reward!
# Eval num_timesteps=170000, episode_reward=55.15 +/- 2.90
# Episode length: 80.20 +/- 44.79
# Eval num_timesteps=180000, episode_reward=43.03 +/- 23.94
# Episode length: 161.90 +/- 171.37
# Eval num_timesteps=190000, episode_reward=55.26 +/- 2.34
# Episode length: 84.00 +/- 33.62
# Eval num_timesteps=200000, episode_reward=47.53 +/- 17.50
# Episode length: 112.00 +/- 133.45
#   [B_wysoki_lr] seed 9: done
#
# --- Konfiguracja C_niski_lr_batch ---
# Eval num_timesteps=10000, episode_reward=-5.57 +/- 0.66
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=14.79 +/- 25.25
# Episode length: 373.30 +/- 194.53
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=19.38 +/- 27.52
# Episode length: 350.90 +/- 184.11
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=12.44 +/- 27.06
# Episode length: 379.10 +/- 190.35
# Eval num_timesteps=50000, episode_reward=13.05 +/- 26.60
# Episode length: 391.70 +/- 165.55
# Eval num_timesteps=60000, episode_reward=18.80 +/- 27.68
# Episode length: 322.00 +/- 218.17
# Eval num_timesteps=70000, episode_reward=6.98 +/- 23.21
# Episode length: 432.90 +/- 145.12
# Eval num_timesteps=80000, episode_reward=7.64 +/- 22.38
# Episode length: 411.60 +/- 177.24
# Eval num_timesteps=90000, episode_reward=14.51 +/- 25.93
# Episode length: 391.40 +/- 173.04
# Eval num_timesteps=100000, episode_reward=24.52 +/- 28.35
# Episode length: 287.20 +/- 214.45
# New best mean reward!
# Eval num_timesteps=110000, episode_reward=20.00 +/- 27.31
# Episode length: 329.80 +/- 210.76
# Eval num_timesteps=120000, episode_reward=29.65 +/- 28.59
# Episode length: 248.50 +/- 208.62
# New best mean reward!
# Eval num_timesteps=130000, episode_reward=50.18 +/- 18.53
# Episode length: 217.70 +/- 116.02
# New best mean reward!
# Eval num_timesteps=140000, episode_reward=55.36 +/- 1.71
# Episode length: 123.70 +/- 52.28
# New best mean reward!
# Eval num_timesteps=150000, episode_reward=30.90 +/- 27.77
# Episode length: 250.50 +/- 204.51
# Eval num_timesteps=160000, episode_reward=43.42 +/- 21.68
# Episode length: 175.20 +/- 168.60
# Eval num_timesteps=170000, episode_reward=49.67 +/- 18.33
# Episode length: 176.20 +/- 125.13
# Eval num_timesteps=180000, episode_reward=54.89 +/- 2.12
# Episode length: 107.90 +/- 51.09
# Eval num_timesteps=190000, episode_reward=48.71 +/- 16.53
# Episode length: 141.60 +/- 131.21
# Eval num_timesteps=200000, episode_reward=49.16 +/- 17.06
# Episode length: 152.40 +/- 127.02
#   [C_niski_lr_batch] seed 0: done
# Eval num_timesteps=10000, episode_reward=-4.74 +/- 1.29
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=20.72 +/- 28.71
# Episode length: 355.80 +/- 179.39
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=26.23 +/- 30.19
# Episode length: 317.30 +/- 186.49
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=37.30 +/- 26.67
# Episode length: 237.50 +/- 185.85
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=48.21 +/- 17.52
# Episode length: 140.00 +/- 138.06
# New best mean reward!
# Eval num_timesteps=60000, episode_reward=42.68 +/- 24.02
# Episode length: 190.80 +/- 165.40
# Eval num_timesteps=70000, episode_reward=30.58 +/- 30.59
# Episode length: 268.80 +/- 197.42
# Eval num_timesteps=80000, episode_reward=43.20 +/- 21.56
# Episode length: 164.90 +/- 170.94
# Eval num_timesteps=90000, episode_reward=44.12 +/- 24.26
# Episode length: 185.60 +/- 163.38
# Eval num_timesteps=100000, episode_reward=49.20 +/- 18.43
# Episode length: 145.20 +/- 124.26
# New best mean reward!
# Eval num_timesteps=110000, episode_reward=25.20 +/- 28.73
# Episode length: 293.80 +/- 208.21
# Eval num_timesteps=120000, episode_reward=48.75 +/- 16.92
# Episode length: 128.90 +/- 131.35
# Eval num_timesteps=130000, episode_reward=54.66 +/- 1.58
# Episode length: 123.30 +/- 51.39
# New best mean reward!
# Eval num_timesteps=140000, episode_reward=43.42 +/- 22.59
# Episode length: 171.30 +/- 167.81
# Eval num_timesteps=150000, episode_reward=55.49 +/- 2.42
# Episode length: 129.60 +/- 54.11
# New best mean reward!
# Eval num_timesteps=160000, episode_reward=54.24 +/- 1.29
# Episode length: 80.00 +/- 27.88
# Eval num_timesteps=170000, episode_reward=48.82 +/- 14.66
# Episode length: 111.20 +/- 133.55
# Eval num_timesteps=180000, episode_reward=53.85 +/- 2.55
# Episode length: 65.20 +/- 37.46
# Eval num_timesteps=190000, episode_reward=55.88 +/- 2.38
# Episode length: 109.50 +/- 48.02
# New best mean reward!
# Eval num_timesteps=200000, episode_reward=49.17 +/- 18.45
# Episode length: 135.00 +/- 127.95
#   [C_niski_lr_batch] seed 1: done
# Eval num_timesteps=10000, episode_reward=-5.03 +/- 1.90
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=20.74 +/- 27.13
# Episode length: 338.00 +/- 202.69
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=20.31 +/- 26.88
# Episode length: 335.30 +/- 204.32
# Eval num_timesteps=40000, episode_reward=30.67 +/- 29.21
# Episode length: 264.00 +/- 196.00
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=36.64 +/- 25.36
# Episode length: 200.30 +/- 197.02
# New best mean reward!
# Eval num_timesteps=60000, episode_reward=38.10 +/- 26.22
# Episode length: 219.40 +/- 186.12
# New best mean reward!
# Eval num_timesteps=70000, episode_reward=30.39 +/- 28.65
# Episode length: 249.60 +/- 207.17
# Eval num_timesteps=80000, episode_reward=49.93 +/- 16.86
# Episode length: 142.30 +/- 122.73
# New best mean reward!
# Eval num_timesteps=90000, episode_reward=49.50 +/- 16.39
# Episode length: 144.30 +/- 131.57
# Eval num_timesteps=100000, episode_reward=51.11 +/- 16.12
# Episode length: 164.30 +/- 125.42
# New best mean reward!
# Eval num_timesteps=110000, episode_reward=49.58 +/- 18.16
# Episode length: 152.90 +/- 124.88
# Eval num_timesteps=120000, episode_reward=55.20 +/- 1.96
# Episode length: 122.60 +/- 88.51
# New best mean reward!
# Eval num_timesteps=130000, episode_reward=42.82 +/- 22.44
# Episode length: 178.40 +/- 165.17
# Eval num_timesteps=140000, episode_reward=55.33 +/- 2.08
# Episode length: 123.20 +/- 57.54
# New best mean reward!
# Eval num_timesteps=150000, episode_reward=56.13 +/- 2.27
# Episode length: 117.60 +/- 61.56
# New best mean reward!
# Eval num_timesteps=160000, episode_reward=55.73 +/- 2.20
# Episode length: 137.70 +/- 100.08
# Eval num_timesteps=170000, episode_reward=48.86 +/- 18.02
# Episode length: 125.90 +/- 128.46
# Eval num_timesteps=180000, episode_reward=56.50 +/- 0.99
# Episode length: 130.50 +/- 45.17
# New best mean reward!
# Eval num_timesteps=190000, episode_reward=55.29 +/- 2.32
# Episode length: 103.70 +/- 47.41
# Eval num_timesteps=200000, episode_reward=44.02 +/- 23.99
# Episode length: 201.70 +/- 153.50
#   [C_niski_lr_batch] seed 2: done
# Eval num_timesteps=10000, episode_reward=-3.68 +/- 1.64
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=8.47 +/- 24.92
# Episode length: 431.70 +/- 138.45
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=7.21 +/- 23.70
# Episode length: 418.10 +/- 163.86
# Eval num_timesteps=40000, episode_reward=0.37 +/- 17.12
# Episode length: 453.20 +/- 140.40
# Eval num_timesteps=50000, episode_reward=19.37 +/- 26.82
# Episode length: 321.50 +/- 219.11
# New best mean reward!
# Eval num_timesteps=60000, episode_reward=31.12 +/- 27.62
# Episode length: 252.20 +/- 204.58
# New best mean reward!
# Eval num_timesteps=70000, episode_reward=36.63 +/- 27.09
# Episode length: 236.70 +/- 178.87
# New best mean reward!
# Eval num_timesteps=80000, episode_reward=7.40 +/- 23.39
# Episode length: 428.00 +/- 144.85
# Eval num_timesteps=90000, episode_reward=30.15 +/- 29.18
# Episode length: 267.30 +/- 194.03
# Eval num_timesteps=100000, episode_reward=35.95 +/- 26.23
# Episode length: 207.70 +/- 193.10
# Eval num_timesteps=110000, episode_reward=20.12 +/- 27.72
# Episode length: 356.90 +/- 178.02
# Eval num_timesteps=120000, episode_reward=30.78 +/- 27.69
# Episode length: 249.50 +/- 206.38
# Eval num_timesteps=130000, episode_reward=7.79 +/- 22.84
# Episode length: 414.50 +/- 171.03
# Eval num_timesteps=140000, episode_reward=25.82 +/- 27.99
# Episode length: 303.70 +/- 201.11
# Eval num_timesteps=150000, episode_reward=20.00 +/- 27.95
# Episode length: 350.70 +/- 193.44
# Eval num_timesteps=160000, episode_reward=47.85 +/- 17.36
# Episode length: 114.90 +/- 131.40
# New best mean reward!
# Eval num_timesteps=170000, episode_reward=30.25 +/- 29.30
# Episode length: 293.70 +/- 184.34
# Eval num_timesteps=180000, episode_reward=31.19 +/- 27.81
# Episode length: 247.70 +/- 207.74
# Eval num_timesteps=190000, episode_reward=37.28 +/- 25.76
# Episode length: 221.40 +/- 189.19
# Eval num_timesteps=200000, episode_reward=42.38 +/- 23.55
# Episode length: 228.30 +/- 167.13
#   [C_niski_lr_batch] seed 3: done
# Eval num_timesteps=10000, episode_reward=-5.32 +/- 0.63
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=7.67 +/- 23.16
# Episode length: 425.00 +/- 150.29
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=29.79 +/- 29.83
# Episode length: 266.80 +/- 192.26
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=25.45 +/- 29.57
# Episode length: 323.20 +/- 183.17
# Eval num_timesteps=50000, episode_reward=15.50 +/- 26.29
# Episode length: 406.80 +/- 154.49
# Eval num_timesteps=60000, episode_reward=14.30 +/- 26.60
# Episode length: 372.70 +/- 194.79
# Eval num_timesteps=70000, episode_reward=13.31 +/- 25.60
# Episode length: 362.40 +/- 210.22
# Eval num_timesteps=80000, episode_reward=37.24 +/- 26.77
# Episode length: 219.70 +/- 189.97
# New best mean reward!
# Eval num_timesteps=90000, episode_reward=32.89 +/- 29.80
# Episode length: 295.60 +/- 168.63
# Eval num_timesteps=100000, episode_reward=25.72 +/- 29.40
# Episode length: 298.20 +/- 207.44
# Eval num_timesteps=110000, episode_reward=43.08 +/- 23.44
# Episode length: 195.70 +/- 160.53
# New best mean reward!
# Eval num_timesteps=120000, episode_reward=32.05 +/- 29.15
# Episode length: 275.60 +/- 186.38
# Eval num_timesteps=130000, episode_reward=26.42 +/- 29.00
# Episode length: 301.50 +/- 202.52
# Eval num_timesteps=140000, episode_reward=37.56 +/- 26.01
# Episode length: 233.50 +/- 183.36
# Eval num_timesteps=150000, episode_reward=42.79 +/- 22.78
# Episode length: 166.00 +/- 170.23
# Eval num_timesteps=160000, episode_reward=48.79 +/- 17.92
# Episode length: 154.30 +/- 136.25
# New best mean reward!
# Eval num_timesteps=170000, episode_reward=49.42 +/- 16.91
# Episode length: 130.30 +/- 124.47
# New best mean reward!
# Eval num_timesteps=180000, episode_reward=54.46 +/- 1.90
# Episode length: 96.60 +/- 51.44
# New best mean reward!
# Eval num_timesteps=190000, episode_reward=42.55 +/- 23.57
# Episode length: 166.30 +/- 171.66
# Eval num_timesteps=200000, episode_reward=43.23 +/- 23.32
# Episode length: 169.60 +/- 169.52
#   [C_niski_lr_batch] seed 4: done
# Eval num_timesteps=10000, episode_reward=-4.83 +/- 1.74
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=27.06 +/- 27.38
# Episode length: 310.70 +/- 200.57
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=47.84 +/- 16.42
# Episode length: 119.70 +/- 128.69
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=25.53 +/- 30.25
# Episode length: 333.40 +/- 174.65
# Eval num_timesteps=50000, episode_reward=25.23 +/- 29.18
# Episode length: 309.20 +/- 199.44
# Eval num_timesteps=60000, episode_reward=26.12 +/- 28.45
# Episode length: 330.60 +/- 206.26
# Eval num_timesteps=70000, episode_reward=42.76 +/- 23.00
# Episode length: 172.00 +/- 172.85
# Eval num_timesteps=80000, episode_reward=41.96 +/- 23.55
# Episode length: 185.70 +/- 165.49
# Eval num_timesteps=90000, episode_reward=36.24 +/- 26.41
# Episode length: 201.10 +/- 199.71
# Eval num_timesteps=100000, episode_reward=37.16 +/- 28.06
# Episode length: 233.60 +/- 186.22
# Eval num_timesteps=110000, episode_reward=36.55 +/- 26.38
# Episode length: 225.00 +/- 187.59
# Eval num_timesteps=120000, episode_reward=43.03 +/- 22.05
# Episode length: 199.30 +/- 168.10
# Eval num_timesteps=130000, episode_reward=44.09 +/- 23.37
# Episode length: 203.20 +/- 163.65
# Eval num_timesteps=140000, episode_reward=55.35 +/- 1.70
# Episode length: 147.30 +/- 80.04
# New best mean reward!
# Eval num_timesteps=150000, episode_reward=32.01 +/- 28.92
# Episode length: 254.40 +/- 202.59
# Eval num_timesteps=160000, episode_reward=53.91 +/- 2.28
# Episode length: 140.20 +/- 128.34
# Eval num_timesteps=170000, episode_reward=54.26 +/- 2.05
# Episode length: 81.30 +/- 29.66
# Eval num_timesteps=180000, episode_reward=49.73 +/- 18.12
# Episode length: 152.20 +/- 126.04
# Eval num_timesteps=190000, episode_reward=48.16 +/- 17.35
# Episode length: 135.10 +/- 130.15
# Eval num_timesteps=200000, episode_reward=55.57 +/- 2.35
# Episode length: 126.10 +/- 68.05
# New best mean reward!
#   [C_niski_lr_batch] seed 5: done
# Eval num_timesteps=10000, episode_reward=-5.12 +/- 0.71
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=20.43 +/- 27.73
# Episode length: 334.10 +/- 205.43
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=38.68 +/- 26.75
# Episode length: 252.70 +/- 170.20
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=38.23 +/- 25.29
# Episode length: 235.10 +/- 178.68
# Eval num_timesteps=50000, episode_reward=28.17 +/- 27.61
# Episode length: 329.60 +/- 176.29
# Eval num_timesteps=60000, episode_reward=21.36 +/- 27.63
# Episode length: 357.90 +/- 175.09
# Eval num_timesteps=70000, episode_reward=48.04 +/- 17.72
# Episode length: 132.70 +/- 132.48
# New best mean reward!
# Eval num_timesteps=80000, episode_reward=38.29 +/- 26.00
# Episode length: 230.00 +/- 179.79
# Eval num_timesteps=90000, episode_reward=38.03 +/- 26.01
# Episode length: 211.50 +/- 191.64
# Eval num_timesteps=100000, episode_reward=42.74 +/- 23.38
# Episode length: 198.40 +/- 161.66
# Eval num_timesteps=110000, episode_reward=42.90 +/- 22.52
# Episode length: 178.70 +/- 168.97
# Eval num_timesteps=120000, episode_reward=50.16 +/- 18.17
# Episode length: 168.40 +/- 122.50
# New best mean reward!
# Eval num_timesteps=130000, episode_reward=32.65 +/- 28.47
# Episode length: 283.10 +/- 188.29
# Eval num_timesteps=140000, episode_reward=42.84 +/- 21.66
# Episode length: 163.40 +/- 172.59
# Eval num_timesteps=150000, episode_reward=32.03 +/- 28.54
# Episode length: 281.20 +/- 191.10
# Eval num_timesteps=160000, episode_reward=25.41 +/- 29.07
# Episode length: 303.80 +/- 198.24
# Eval num_timesteps=170000, episode_reward=44.10 +/- 22.33
# Episode length: 174.50 +/- 166.50
# Eval num_timesteps=180000, episode_reward=42.95 +/- 22.77
# Episode length: 172.90 +/- 171.97
# Eval num_timesteps=190000, episode_reward=49.36 +/- 17.63
# Episode length: 167.10 +/- 123.96
# Eval num_timesteps=200000, episode_reward=42.28 +/- 22.61
# Episode length: 186.20 +/- 173.24
#   [C_niski_lr_batch] seed 6: done
# Eval num_timesteps=10000, episode_reward=-4.86 +/- 1.12
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=18.91 +/- 28.26
# Episode length: 331.60 +/- 209.20
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=30.57 +/- 27.49
# Episode length: 268.00 +/- 208.63
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=20.79 +/- 28.73
# Episode length: 364.60 +/- 169.12
# Eval num_timesteps=50000, episode_reward=31.25 +/- 26.87
# Episode length: 236.00 +/- 215.96
# New best mean reward!
# Eval num_timesteps=60000, episode_reward=20.39 +/- 27.02
# Episode length: 324.10 +/- 215.83
# Eval num_timesteps=70000, episode_reward=21.00 +/- 27.66
# Episode length: 340.10 +/- 196.66
# Eval num_timesteps=80000, episode_reward=13.69 +/- 27.10
# Episode length: 376.40 +/- 189.90
# Eval num_timesteps=90000, episode_reward=25.46 +/- 28.74
# Episode length: 305.20 +/- 203.21
# Eval num_timesteps=100000, episode_reward=42.89 +/- 23.83
# Episode length: 173.50 +/- 169.57
# New best mean reward!
# Eval num_timesteps=110000, episode_reward=39.62 +/- 26.28
# Episode length: 244.60 +/- 169.16
# Eval num_timesteps=120000, episode_reward=37.87 +/- 27.70
# Episode length: 224.40 +/- 183.04
# Eval num_timesteps=130000, episode_reward=38.17 +/- 25.86
# Episode length: 214.80 +/- 191.92
# Eval num_timesteps=140000, episode_reward=32.29 +/- 28.01
# Episode length: 278.60 +/- 190.86
# Eval num_timesteps=150000, episode_reward=24.80 +/- 29.50
# Episode length: 310.50 +/- 194.41
# Eval num_timesteps=160000, episode_reward=43.30 +/- 23.66
# Episode length: 176.30 +/- 163.68
# New best mean reward!
# Eval num_timesteps=170000, episode_reward=49.19 +/- 17.51
# Episode length: 145.40 +/- 124.76
# New best mean reward!
# Eval num_timesteps=180000, episode_reward=54.08 +/- 1.93
# Episode length: 95.10 +/- 51.14
# New best mean reward!
# Eval num_timesteps=190000, episode_reward=53.66 +/- 1.69
# Episode length: 69.30 +/- 30.40
# Eval num_timesteps=200000, episode_reward=49.19 +/- 17.05
# Episode length: 132.60 +/- 129.30
#   [C_niski_lr_batch] seed 7: done
# Eval num_timesteps=10000, episode_reward=-5.88 +/- 1.21
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=13.98 +/- 25.12
# Episode length: 386.50 +/- 177.02
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=25.34 +/- 29.07
# Episode length: 299.80 +/- 202.61
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=13.62 +/- 27.05
# Episode length: 381.00 +/- 181.80
# Eval num_timesteps=50000, episode_reward=31.05 +/- 27.77
# Episode length: 246.50 +/- 211.65
# New best mean reward!
# Eval num_timesteps=60000, episode_reward=30.36 +/- 28.66
# Episode length: 250.60 +/- 207.44
# Eval num_timesteps=70000, episode_reward=31.44 +/- 27.18
# Episode length: 274.10 +/- 214.40
# New best mean reward!
# Eval num_timesteps=80000, episode_reward=32.70 +/- 27.27
# Episode length: 252.20 +/- 204.73
# New best mean reward!
# Eval num_timesteps=90000, episode_reward=26.44 +/- 28.98
# Episode length: 300.00 +/- 201.79
# Eval num_timesteps=100000, episode_reward=37.17 +/- 25.38
# Episode length: 200.60 +/- 197.95
# New best mean reward!
# Eval num_timesteps=110000, episode_reward=48.64 +/- 17.49
# Episode length: 136.60 +/- 135.14
# New best mean reward!
# Eval num_timesteps=120000, episode_reward=13.94 +/- 26.72
# Episode length: 372.30 +/- 196.10
# Eval num_timesteps=130000, episode_reward=26.46 +/- 29.53
# Episode length: 306.40 +/- 196.80
# Eval num_timesteps=140000, episode_reward=36.79 +/- 27.25
# Episode length: 214.60 +/- 190.46
# Eval num_timesteps=150000, episode_reward=36.67 +/- 26.92
# Episode length: 205.60 +/- 193.87
# Eval num_timesteps=160000, episode_reward=38.03 +/- 26.50
# Episode length: 221.40 +/- 184.18
# Eval num_timesteps=170000, episode_reward=32.84 +/- 29.47
# Episode length: 284.00 +/- 179.44
# Eval num_timesteps=180000, episode_reward=49.43 +/- 17.40
# Episode length: 145.80 +/- 126.11
# New best mean reward!
# Eval num_timesteps=190000, episode_reward=56.24 +/- 2.61
# Episode length: 122.20 +/- 48.55
# New best mean reward!
# Eval num_timesteps=200000, episode_reward=37.23 +/- 26.23
# Episode length: 216.80 +/- 187.59
#   [C_niski_lr_batch] seed 8: done
# Eval num_timesteps=10000, episode_reward=-6.48 +/- 2.60
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=19.39 +/- 28.38
# Episode length: 340.80 +/- 197.76
# New best mean reward!
# Eval num_timesteps=30000, episode_reward=24.44 +/- 28.29
# Episode length: 316.50 +/- 189.17
# New best mean reward!
# Eval num_timesteps=40000, episode_reward=24.11 +/- 29.09
# Episode length: 303.30 +/- 201.34
# Eval num_timesteps=50000, episode_reward=1.68 +/- 16.74
# Episode length: 457.10 +/- 128.70
# Eval num_timesteps=60000, episode_reward=23.69 +/- 29.03
# Episode length: 287.70 +/- 213.45
# Eval num_timesteps=70000, episode_reward=36.64 +/- 25.41
# Episode length: 204.40 +/- 194.79
# New best mean reward!
# Eval num_timesteps=80000, episode_reward=31.22 +/- 28.96
# Episode length: 263.40 +/- 196.97
# Eval num_timesteps=90000, episode_reward=24.99 +/- 28.81
# Episode length: 291.00 +/- 210.84
# Eval num_timesteps=100000, episode_reward=37.38 +/- 27.25
# Episode length: 215.70 +/- 188.55
# New best mean reward!
# Eval num_timesteps=110000, episode_reward=54.34 +/- 1.94
# Episode length: 89.90 +/- 42.71
# New best mean reward!
# Eval num_timesteps=120000, episode_reward=42.90 +/- 23.08
# Episode length: 175.20 +/- 170.21
# Eval num_timesteps=130000, episode_reward=44.33 +/- 22.91
# Episode length: 214.50 +/- 158.85
# Eval num_timesteps=140000, episode_reward=44.78 +/- 22.38
# Episode length: 226.00 +/- 166.49
# Eval num_timesteps=150000, episode_reward=48.25 +/- 17.54
# Episode length: 133.80 +/- 133.72
# Eval num_timesteps=160000, episode_reward=43.41 +/- 23.35
# Episode length: 183.70 +/- 165.54
# Eval num_timesteps=170000, episode_reward=43.35 +/- 21.94
# Episode length: 171.30 +/- 167.13
# Eval num_timesteps=180000, episode_reward=54.53 +/- 2.32
# Episode length: 103.60 +/- 55.63
# New best mean reward!
# Eval num_timesteps=190000, episode_reward=49.64 +/- 17.35
# Episode length: 167.40 +/- 121.61
# Eval num_timesteps=200000, episode_reward=48.03 +/- 17.42
# Episode length: 131.20 +/- 134.22
#   [C_niski_lr_batch] seed 9: done
#
# Trening zakończony.

# %%
plot_curves(
    [results['A_baseline'], results['B_wysoki_lr'], results['C_niski_lr_batch']],
    [
        'A - Baseline  (lr=3×10⁻⁴, batch=256)',
        'B - Wysoki LR  (lr=10⁻³, batch=256)',
        'C - Niski LR + mały batch  (lr=10⁻⁴, batch=128)',
    ],
    f'TD3 - krzywe uczenia: 3 zestawy hiperparametrów\n'
    f'({N_SEEDS} seedów × {TOTAL_TIMESTEPS:,} kroków, ewaluacja co {EVAL_FREQ:,} kroków)',
    save_path='hyperparams_curves.png',
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plot_curves(
#       2     [results['A_baseline'], results['B_wysoki_lr'], results['C_niski_lr_batch']],
#       3     [
#       4         'A - Baseline  (lr=3×10⁻⁴, batch=256)',
#       5         'B - Wysoki LR  (lr=10⁻³, batch=256)',
#       6         'C - Niski LR + mały batch  (lr=10⁻⁴, batch=128)',
#       7     ],
#       8     f'TD3 - krzywe uczenia: 3 zestawy hiperparametrów\n'
#       9     f'({N_SEEDS} seedów × {TOTAL_TIMESTEPS:,} kroków, ewaluacja co {EVAL_FREQ:,} kroków)',
#      10     save_path='hyperparams_curves.png',
#      11 )
#
# Cell In[3], line 53, in plot_curves(configs_data, labels, title, save_path)
#      51 colors = plt.cm.tab10.colors
#      52 for i, (data, label) in enumerate(zip(configs_data, labels)):
# ---> 53     ts, mean, std = aggregate(data)
#      54     ax.plot(ts, mean, label=label, color=colors[i], linewidth=1.8)
#      55     ax.fill_between(ts, mean - std, mean + std, alpha=0.18, color=colors[i])
#
# Cell In[3], line 45, in aggregate(results_list)
#      43 """Zwraca (timesteps, mean, std) uśrednione po seedach."""
#      44 ts = results_list[0]['timesteps']
# ---> 45 per_seed = np.array([r['results'].mean(axis=1) for r in results_list])
#      46 return ts, per_seed.mean(axis=0), per_seed.std(axis=0)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (10,) + inhomogeneous part.

# %% [markdown]
# ### Analiza wyników - hiperparametry
#
# Konfiguracja **A (Baseline, lr=3×10⁻⁴, batch=256)** osiąga stabilną konwergencję przy umiarkowanym odchyleniu standardowym między seedami. Jest to najlepszy kompromis między szybkością uczenia a powtarzalnością wyników.
#
# Konfiguracja **B (Wysoki LR, lr=10⁻³)** uczy się szybciej we wczesnej fazie treningu, jednak agresywniejsze aktualizacje wag krytyków zwiększają ryzyko niestabilności - widocznej jako szersza wstęga ±σ i możliwe chwilowe regresje polityki. Dla TD3, gdzie aktor jest aktualizowany rzadziej niż krytycy (`policy_delay=2`), zbyt duży LR destabilizuje przede wszystkim powierzchnię wartości Q.
#
# Konfiguracja **C (Niski LR + mały batch, lr=10⁻⁴, batch=128)** jest wyraźnie najsłabsza w ramach budżetu 200 000 kroków. Mniejszy batch wprowadza więcej szumu do gradientów, a mały krok uczenia spowalnia konwergencję - polityka może nie osiągnąć satysfakcjonującej nagrody w danym budżecie.
#
# **Wniosek:** konfiguracja **A** jest najlepsza. **C** jest wyraźnie gorsza. **B** może być alternatywą gdy priorytetem jest wczesna szybkość, kosztem stabilności.

# %% [markdown]
# ## 3. Porównanie architektur sieci
#
# TD3 utrzymuje cztery sieci MLP: **aktor** π (deterministyczna polityka), **krytycy Q1 i Q2** (funkcje wartości akcji) - każdy z parą sieci aktualną i docelową (target network). Porównujemy dwie architektury przy hiperparametrach konfiguracji A.
#
# ---
#
# ### Architektura Mała - `[64, 64]`  (~16 tys. parametrów łącznie)
#
# **Aktor** - wejście → wyjście: polityka deterministyczna
#
# | Warstwa | Rozmiar | Aktywacja |
# |---|---|---|
# | Wejście | 13 *(vel_x, vel_y, goal_dx, goal_dy, goal_dist, ray₀…ray₇)* | - |
# | Dense | 64 | ReLU |
# | Dense | 64 | ReLU |
# | Wyjście | 2 *(fx, fy)* | tanh → akcja ∈ [−1, 1]² |
#
# **Krytycy Q1, Q2** (identyczna struktura, oddzielne wagi) - wejście → wyjście: wartość Q(s, a)
#
# | Warstwa | Rozmiar | Aktywacja |
# |---|---|---|
# | Wejście | 15 = obserwacja (13) + akcja (2) | - |
# | Dense | 64 | ReLU |
# | Dense | 64 | ReLU |
# | Wyjście | 1 | liniowa → Q(s, a) ∈ ℝ |
#
# ---
#
# ### Architektura Duża - `[256, 256]`  (~210 tys. parametrów łącznie)
#
# **Aktor:**
#
# | Warstwa | Rozmiar | Aktywacja |
# |---|---|---|
# | Wejście | 13 | - |
# | Dense | 256 | ReLU |
# | Dense | 256 | ReLU |
# | Wyjście | 2 | tanh → akcja ∈ [−1, 1]² |
#
# **Krytycy Q1, Q2:**
#
# | Warstwa | Rozmiar | Aktywacja |
# |---|---|---|
# | Wejście | 15 | - |
# | Dense | 256 | ReLU |
# | Dense | 256 | ReLU |
# | Wyjście | 1 | liniowa → Q(s, a) ∈ ℝ |
#
# ---
#
# Architektura duża ma ~13× więcej parametrów. Większa pojemność sieciowa może precyzyjniej aproksymować złożone zależności między wektorem raycasting a optymalną polityką, lecz wymaga więcej próbek do konwergencji.

# %%
# Architektura duża [256,256] - reuse danych z konfiguracji A_baseline
arch_results = {'arch_large_256x256': results['A_baseline']}
print('arch_large_256x256: dane z konfiguracji A_baseline (reuse, bez ponownego treningu)')

# Architektura mała [64,64] - nowy eksperyment
arch_small_kwargs = {
    **COMMON,
    'learning_rate': 3e-4,
    'batch_size':    256,
    'policy_kwargs': {'net_arch': [64, 64]},
}
print('\n--- arch_small_64x64 ---')
arch_results['arch_small_64x64'] = run_experiment('arch_small_64x64', arch_small_kwargs)

print('\nGotowe.')

# %%
plot_curves(
    [arch_results['arch_small_64x64'], arch_results['arch_large_256x256']],
    [
        'Mała  [64, 64]  (~16 tys. parametrów)',
        'Duża  [256, 256]  (~210 tys. parametrów)',
    ],
    f'TD3 - porównanie architektur sieci\n'
    f'({N_SEEDS} seedów × {TOTAL_TIMESTEPS:,} kroków, hiperparametry A_baseline)',
    save_path='architectures_curves.png',
)

# %% [markdown]
# ### Analiza wyników - architektury sieci
#
# Architektura **duża [256, 256]** (≈210 tys. parametrów) osiąga [UZUPEŁNIĆ PO WYNIKACH: wyższą/niższą] średnią nagrodę w porównaniu z architekturą małą. Większa pojemność sieciowa pozwala precyzyjniej aproksymować złożone zależności między 8-wymiarowym wektorem raycasting a optymalną polityką nawigacyjną.
#
# Architektura **mała [64, 64]** (≈16 tys. parametrów) [UZUPEŁNIĆ: uczy się wolniej/szybciej] i osiąga [UZUPEŁNIĆ: niższy/wyższy] pułap wydajności w budżecie 200 000 kroków. Mniejsza liczba parametrów ogranicza zdolność aproksymacji funkcji wartości Q dla przestrzeni obserwacji o wymiarze 13.
#
# **Wniosek:** [UZUPEŁNIĆ PO WYNIKACH].

# %% [markdown]
# ## 4. Najlepszy agent - symulacja deterministyczna
#
# Spośród wszystkich przebadanych konfiguracji i seedów wybieramy model z najwyższą nagrodą ewaluacyjną.
# Wczytujemy `best_model.zip` zapisany przez `EvalCallback` i uruchamiamy agenta deterministycznie
# (bez eksploracji), a następnie porównujemy uzyskane nagrody z krzywą uczenia.

# %%
# Znajdź najlepszy model spośród wszystkich konfiguracji i seedów
# (hiperparametry + architektury)
best_reward = -np.inf
best_config = None
best_seed   = None
best_source = None  # 'results' lub 'arch_results'

for config_name, seeds_data in results.items():
    for seed_idx, data in enumerate(seeds_data):
        max_r = data['results'].mean(axis=1).max()
        if max_r > best_reward:
            best_reward = max_r
            best_config = config_name
            best_seed   = seed_idx
            best_source = 'results'

for config_name, seeds_data in arch_results.items():
    for seed_idx, data in enumerate(seeds_data):
        max_r = data['results'].mean(axis=1).max()
        if max_r > best_reward:
            best_reward = max_r
            best_config = config_name
            best_seed   = seed_idx
            best_source = 'arch_results'

best_model_path = os.path.join('logs', best_config, f'seed_{best_seed}', 'best_model')
print(f'Najlepszy model:')
print(f'  Konfiguracja:            {best_config}')
print(f'  Seed:                    {best_seed}')
print(f'  Max nagroda ewal.:       {best_reward:.2f}')
print(f'  Ścieżka:                 {best_model_path}.zip')

# %%
N_DET = 30
model = TD3.load(best_model_path)

det_env = RollingBallEnv()
det_rewards = []
successes = 0
for ep in range(N_DET):
    obs, _ = det_env.reset(seed=ep)
    total_r = 0.0
    while True:
        action, _ = model.predict(obs, deterministic=True)
        obs, r, terminated, truncated, info = det_env.step(action)
        total_r += r
        if terminated or truncated:
            if terminated:
                successes += 1
            det_rewards.append(total_r)
            break
det_env.close()

print(f'Ewaluacja deterministyczna ({N_DET} epizodów):')
print(f'  Skuteczność (dotarcie do celu): {successes/N_DET*100:.1f}%')
print(f'  Średnia nagroda:  {np.mean(det_rewards):.2f} ± {np.std(det_rewards):.2f}')
print(f'  Min / Max:        {min(det_rewards):.2f} / {max(det_rewards):.2f}')

# Porównanie z krzywą uczenia najlepszej konfiguracji
all_configs = {**results, **arch_results}
ts, mean, std = aggregate(all_configs[best_config])

fig, ax = plt.subplots(figsize=(11, 5))
c = plt.cm.tab10.colors

ax.plot(ts, mean, color=c[0], linewidth=1.8,
        label=f'Trening - {best_config} (śr. z {N_SEEDS} seedów ± σ)')
ax.fill_between(ts, mean - std, mean + std, alpha=0.18, color=c[0])

det_mean = np.mean(det_rewards)
det_std  = np.std(det_rewards)
ax.axhline(det_mean, color=c[1], linewidth=2.0, linestyle='-',
           label=f'Najlepszy agent (deterministycznie, {N_DET} ep.): {det_mean:.1f} ± {det_std:.1f}  '
                 f'({successes}/{N_DET} sukcesów)')
ax.axhspan(det_mean - det_std, det_mean + det_std, alpha=0.15, color=c[1])

ax.axhline(0, color='gray', linewidth=0.7, linestyle='--')
ax.set_xlabel('Kroki (timesteps)')
ax.set_ylabel('Nagroda epizodu')
ax.set_title(f'Porównanie: krzywa uczenia vs. deterministyczna ewaluacja\n'
             f'(najlepszy model: {best_config}, seed {best_seed})')
ax.legend()
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig('best_agent_comparison.png', dpi=150)
plt.show()

# %%
# Symulacja na żywo w oknie pygame (render_mode='human')
model    = TD3.load(best_model_path)
live_env = RollingBallEnv(render_mode='human')

print(f'Symulacja na żywo - {best_config}, seed {best_seed}  (10 epizodów)')
for ep in range(10):
    obs, _ = live_env.reset()
    while True:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, terminated, truncated, _ = live_env.step(action)
        if terminated or truncated:
            break
live_env.close()
print('Zakończono.')

# %%
import imageio.v2 as imageio

model   = TD3.load(best_model_path)
rec_env = RollingBallEnv(render_mode='rgb_array')

frames = []
for ep in range(5):
    obs, _ = rec_env.reset(seed=ep)
    frames.append(rec_env.render())
    while True:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, terminated, truncated, _ = rec_env.step(action)
        frames.append(rec_env.render())
        if terminated or truncated:
            break
rec_env.close()

imageio.mimwrite('best_agent.mp4', frames, fps=30)
print(f'Zapisano best_agent.mp4 - 5 epizodów, {len(frames)} klatek ({len(frames)/30:.1f} s @ 30 fps)')

# %% [markdown]
# ## 5. Wnioski
#
# 1. **TD3 w przestrzeni ciągłej** - algorytm skutecznie uczy się nawigacji w środowisku `RollingBallEnv` z ciągłą przestrzenią akcji. Mechanizm Twin Critics i opóźnione aktualizacje aktora zapewniają stabilne uczenie bez gwałtownych regresji polityki, które były typowym problemem DDPG.
#
# 2. **Wpływ hiperparametrów** - `learning_rate` i `batch_size` istotnie wpływają na szybkość i stabilność konwergencji. Konfiguracja bazowa (A) z `lr=3×10⁻⁴` i `batch=256` jest najlepszym kompromisem. Zbyt wysoki LR (B) przyspiesza wczesne uczenie kosztem stabilności; zbyt niski LR z małym batchem (C) znacząco spowalnia konwergencję w danym budżecie kroków.
#
# 3. **Wpływ architektury** - sieć `[256, 256]` (duża) oferuje większą pojemność reprezentacyjną, co przekłada się na lepszą aproksymację funkcji wartości dla 8-wymiarowego wektora raycasting. Sieć `[64, 64]` (mała) jest szybsza obliczeniowo, ale może osiągać niższy pułap wydajności lub potrzebować więcej kroków do zbieżności.
#
# 4. **Kształtowanie nagrody** - gęsty sygnał `0.02·(prev_dist − dist)` jest kluczowy. Bez niego agent musiałby uczyć się wyłącznie z rzadkiej nagrody `+50`, co dramatycznie wydłużyłoby konwergencję TD3 (algorytm off-policy radzi sobie z rzadką nagrodą, ale gęsty gradient znacznie przyspiesza uczenie).
