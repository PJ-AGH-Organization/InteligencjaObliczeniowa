# %% [markdown]
# # Rolling Ball Navigator
#
# Własne środowisko Gymnasium zaimplementowane na potrzeby Projektu 4 z przedmiotu Inteligencja Obliczeniowa.
#
# Kulka tocząca się po planszy musi dotrzeć do wyznaczonego celu, omijając statyczne przeszkody. Agent uczy się nawigacji wyłącznie na podstawie lokalnych obserwacji: prędkości, kierunku do celu i sensorów odległości (raycasting) — bez znajomości swojej pozycji absolutnej.

# %% [markdown]
# ## 1. Środowisko `RollingBallEnv`
#
# Środowisko spełnia standardowy interfejs Gymnasium (`reset`, `step`, `render`, `close`). Przestrzeń obserwacji jest ciągła (wektor 13 liczb `float32`), przestrzeń akcji jest ciągła (wektor 2 liczb `float32`).
#
# | Element | Opis |
# |---------|------|
# | Obserwacje | `[vel_x, vel_y, goal_dx, goal_dy, goal_dist, ray_0 … ray_7]` |
# | Akcje | `[fx, fy]` — siła przykładana do kulki w osi X i Y |
# | Koniec epizodu | Dotarcie do celu (`terminated`) lub przekroczenie limitu kroków (`truncated`) |

# %%
import math
import numpy as np
import gymnasium as gym
from gymnasium import spaces
import pygame

# ── World constants ────────────────────────────────────────────────────────────
WORLD_W      = 600.0
WORLD_H      = 600.0
BALL_RADIUS  = 12.0
GOAL_RADIUS  = 18.0
FRICTION     = 0.92
FORCE_SCALE  = 0.4           # terminal vel ≈ 5.0
V_MAX        = 8.0
MAX_STEPS    = 500
RAY_MAX      = 500.0
DIAGONAL     = math.sqrt(WORLD_W ** 2 + WORLD_H ** 2)
RAY_ANGLES   = [0, 45, 90, 135, 180, 225, 270, 315]

# Static obstacle layout: (left_x, top_y, width, height)
OBSTACLES = [
    ( 80,  80,  80, 200),
    (280,  40,  80, 160),
    (440, 100, 100,  60),
    (140, 340, 160,  60),
    (350, 280,  60, 200),
    (460, 380,  90, 130),
]


class RollingBallEnv(gym.Env):
    """2-D physics environment: roll a ball to a goal while avoiding obstacles."""

    metadata = {"render_modes": ["human", "rgb_array"], "render_fps": 30}

    def __init__(self, render_mode=None):
        super().__init__()
        assert render_mode is None or render_mode in self.metadata["render_modes"]
        self.render_mode = render_mode
        self._window = None
        self._clock  = None

        # All observations are normalised to [-1, 1] or [0, 1]
        low  = np.array([-1., -1., -1., -1., 0.] + [0.] * 8, dtype=np.float32)
        high = np.array([ 1.,  1.,  1.,  1., 1.] + [1.] * 8, dtype=np.float32)
        self.observation_space = spaces.Box(low, high, dtype=np.float32)
        self.action_space = spaces.Box(
            np.array([-1.0, -1.0], dtype=np.float32),
            np.array([ 1.0,  1.0], dtype=np.float32),
            dtype=np.float32,
        )

        self._pos        = np.zeros(2, dtype=np.float32)
        self._vel        = np.zeros(2, dtype=np.float32)
        self._goal       = np.zeros(2, dtype=np.float32)
        self._step_count = 0

    # ── Gymnasium interface ────────────────────────────────────────────────────

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        while True:
            p = np.array([
                self.np_random.uniform(BALL_RADIUS, WORLD_W - BALL_RADIUS),
                self.np_random.uniform(BALL_RADIUS, WORLD_H - BALL_RADIUS),
            ], dtype=np.float32)
            if self._is_free(p, BALL_RADIUS):
                self._pos = p
                break

        while True:
            g = np.array([
                self.np_random.uniform(GOAL_RADIUS, WORLD_W - GOAL_RADIUS),
                self.np_random.uniform(GOAL_RADIUS, WORLD_H - GOAL_RADIUS),
            ], dtype=np.float32)
            if self._is_free(g, GOAL_RADIUS) and np.linalg.norm(g - self._pos) > 100.0:
                self._goal = g
                break

        self._vel        = np.zeros(2, dtype=np.float32)
        self._step_count = 0

        obs  = self._get_obs()
        info = self._get_info()
        if self.render_mode == "human":
            self._render_frame()
        return obs, info

    def step(self, action):
        action = np.clip(action, -1.0, 1.0).astype(np.float32)

        prev_dist = float(np.linalg.norm(self._pos - self._goal))

        self._vel  = np.clip(self._vel + action * FORCE_SCALE, -V_MAX, V_MAX)
        self._vel *= FRICTION
        self._pos += self._vel

        self._resolve_walls()
        for obs_rect in OBSTACLES:
            self._resolve_obstacle(obs_rect)

        self._step_count += 1

        dist       = float(np.linalg.norm(self._pos - self._goal))
        terminated = dist <= GOAL_RADIUS + BALL_RADIUS
        truncated  = self._step_count >= MAX_STEPS

        # No collision penalty — physics bounce is sufficient deterrent.
        # Strong shaping keeps the agent moving toward the goal at all times.
        reward = -0.01 + 0.02 * (prev_dist - dist)
        if terminated:
            reward += 50.0

        obs  = self._get_obs()
        info = self._get_info()
        if self.render_mode == "human":
            self._render_frame()
        return obs, float(reward), terminated, truncated, info

    def render(self):
        if self.render_mode == "rgb_array":
            return self._render_frame()

    def close(self):
        if self._window is not None:
            pygame.display.quit()
            pygame.quit()
            self._window = None
            self._clock  = None

    # ── Physics helpers ────────────────────────────────────────────────────────

    def _is_free(self, pos: np.ndarray, radius: float) -> bool:
        if (
            pos[0] - radius < 0 or pos[0] + radius > WORLD_W
            or pos[1] - radius < 0 or pos[1] + radius > WORLD_H
        ):
            return False
        for ox, oy, ow, oh in OBSTACLES:
            cx = float(np.clip(pos[0], ox, ox + ow))
            cy = float(np.clip(pos[1], oy, oy + oh))
            if math.sqrt((pos[0] - cx) ** 2 + (pos[1] - cy) ** 2) < radius + 2.0:
                return False
        return True

    def _resolve_walls(self) -> None:
        if self._pos[0] - BALL_RADIUS < 0:
            self._pos[0] = BALL_RADIUS
            self._vel[0] = abs(self._vel[0])
        elif self._pos[0] + BALL_RADIUS > WORLD_W:
            self._pos[0] = WORLD_W - BALL_RADIUS
            self._vel[0] = -abs(self._vel[0])
        if self._pos[1] - BALL_RADIUS < 0:
            self._pos[1] = BALL_RADIUS
            self._vel[1] = abs(self._vel[1])
        elif self._pos[1] + BALL_RADIUS > WORLD_H:
            self._pos[1] = WORLD_H - BALL_RADIUS
            self._vel[1] = -abs(self._vel[1])

    def _resolve_obstacle(self, rect) -> None:
        ox, oy, ow, oh = rect
        cx = float(np.clip(self._pos[0], ox, ox + ow))
        cy = float(np.clip(self._pos[1], oy, oy + oh))
        dx = self._pos[0] - cx
        dy = self._pos[1] - cy
        dist_sq = dx * dx + dy * dy

        if dist_sq >= BALL_RADIUS * BALL_RADIUS:
            return

        dist = math.sqrt(dist_sq)
        nx, ny = (dx / dist, dy / dist) if dist > 1e-6 else (1.0, 0.0)

        overlap = BALL_RADIUS - dist
        self._pos[0] += nx * (overlap + 0.5)
        self._pos[1] += ny * (overlap + 0.5)

        dot = self._vel[0] * nx + self._vel[1] * ny
        if dot < 0:
            self._vel[0] -= 2.0 * dot * nx
            self._vel[1] -= 2.0 * dot * ny

    # ── Ray-sensor helpers ─────────────────────────────────────────────────────

    def _cast_ray(self, angle_deg: float) -> float:
        rad = math.radians(angle_deg)
        dx  =  math.cos(rad)
        dy  = -math.sin(rad)
        ox, oy = float(self._pos[0]), float(self._pos[1])

        t = RAY_MAX
        if dx > 1e-9:
            t = min(t, (WORLD_W - ox) / dx)
        elif dx < -1e-9:
            t = min(t, -ox / dx)
        if dy > 1e-9:
            t = min(t, (WORLD_H - oy) / dy)
        elif dy < -1e-9:
            t = min(t, -oy / dy)

        for obs_rect in OBSTACLES:
            t_obs = self._ray_aabb(ox, oy, dx, dy, obs_rect)
            if t_obs < t:
                t = t_obs

        return float(np.clip(t, 0.0, RAY_MAX))

    @staticmethod
    def _ray_aabb(ox: float, oy: float, dx: float, dy: float, rect) -> float:
        rx, ry, rw, rh = rect
        t_near, t_far = -1e30, 1e30

        if abs(dx) > 1e-9:
            tx1 = (rx      - ox) / dx
            tx2 = (rx + rw - ox) / dx
            t_near = max(t_near, min(tx1, tx2))
            t_far  = min(t_far,  max(tx1, tx2))
        elif ox < rx or ox > rx + rw:
            return RAY_MAX

        if abs(dy) > 1e-9:
            ty1 = (ry      - oy) / dy
            ty2 = (ry + rh - oy) / dy
            t_near = max(t_near, min(ty1, ty2))
            t_far  = min(t_far,  max(ty1, ty2))
        elif oy < ry or oy > ry + rh:
            return RAY_MAX

        if t_far < t_near or t_near <= 0.0:
            return RAY_MAX
        return float(np.clip(t_near, 0.0, RAY_MAX))

    # ── Observation / info ─────────────────────────────────────────────────────

    def _get_obs(self) -> np.ndarray:
        ddx = self._goal[0] - self._pos[0]
        ddy = self._goal[1] - self._pos[1]
        dist = math.sqrt(ddx * ddx + ddy * ddy)
        if dist > 1e-9:
            ndx =  ddx / dist
            ndy = -ddy / dist
        else:
            ndx = ndy = 0.0

        rays = [self._cast_ray(a) for a in RAY_ANGLES]
        return np.array([
            self._vel[0] / V_MAX,
            self._vel[1] / V_MAX,
            ndx,
            ndy,
            dist / DIAGONAL,
            *[r / RAY_MAX for r in rays],
        ], dtype=np.float32)

    def _get_info(self) -> dict:
        return {
            "distance_to_goal": float(np.linalg.norm(self._pos - self._goal)),
            "step": self._step_count,
        }

    # ── Rendering ──────────────────────────────────────────────────────────────

    def _render_frame(self):
        if not pygame.get_init():
            pygame.init()
        if self.render_mode == "human":
            if self._window is None:
                pygame.display.init()
                self._window = pygame.display.set_mode((int(WORLD_W), int(WORLD_H)))
                pygame.display.set_caption("Rolling Ball Navigator")
            if self._clock is None:
                self._clock = pygame.time.Clock()

        canvas = pygame.Surface((int(WORLD_W), int(WORLD_H)))
        canvas.fill((20, 20, 20))

        pygame.draw.rect(canvas, (220, 220, 220), (0, 0, int(WORLD_W), int(WORLD_H)), 3)

        for ox, oy, ow, oh in OBSTACLES:
            pygame.draw.rect(canvas, (110, 110, 110), (int(ox), int(oy), int(ow), int(oh)))

        obs_vec = self._get_obs()
        for i, angle_deg in enumerate(RAY_ANGLES):
            rad = math.radians(angle_deg)
            rdx =  math.cos(rad)
            rdy = -math.sin(rad)
            ray_len = float(obs_vec[5 + i]) * RAY_MAX
            ex = int(self._pos[0] + rdx * ray_len)
            ey = int(self._pos[1] + rdy * ray_len)
            pygame.draw.line(
                canvas, (180, 40, 40),
                (int(self._pos[0]), int(self._pos[1])), (ex, ey), 1,
            )

        pygame.draw.circle(
            canvas, (30, 210, 80),
            (int(self._goal[0]), int(self._goal[1])), int(GOAL_RADIUS),
        )
        pygame.draw.circle(
            canvas, (50, 130, 255),
            (int(self._pos[0]), int(self._pos[1])), int(BALL_RADIUS),
        )

        if self.render_mode == "human":
            self._window.blit(canvas, canvas.get_rect())
            pygame.event.pump()
            pygame.display.update()
            self._clock.tick(self.metadata["render_fps"])
        else:
            return np.transpose(
                np.array(pygame.surfarray.pixels3d(canvas)), axes=(1, 0, 2)
            )

# %% [markdown]
# ## 2. Trening agenta (SAC)
#
# Do treningu używamy algorytmu **Soft Actor-Critic (SAC)** z biblioteki `stable-baselines3`. SAC jest dedykowany do ciągłych przestrzeni akcji — maksymalizuje zarówno oczekiwaną nagrodę, jak i entropię polityki, co przekłada się na stabilność uczenia i dobre eksplorowanie środowiska.
#
# Środowisko treningowe nie używa trybu graficznego (`render_mode=None`), co zapewnia maksymalną szybkość. Postęp ewaluacji jest zapisywany do pliku `logs/evaluations.npz` i wizualizowany po zakończeniu treningu.

# %%
import os
from stable_baselines3 import SAC
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import EvalCallback

os.makedirs("models", exist_ok=True)
os.makedirs("logs",   exist_ok=True)

train_env = RollingBallEnv()
eval_env  = Monitor(RollingBallEnv())

model = SAC(
    "MlpPolicy",
    train_env,
    learning_rate=3e-4,
    buffer_size=300_000,
    learning_starts=5_000,
    batch_size=256,
    tau=0.005,
    gamma=0.99,
    ent_coef=0.1,        # fixed — prevents auto-tuning from inflating entropy
    verbose=1,
    seed=42,
)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="models/",
    log_path="logs/",
    eval_freq=5_000,
    n_eval_episodes=10,
    deterministic=True,
    render=False,
)

model.learn(total_timesteps=500_000, callback=eval_callback)
model.save("models/rolling_ball_final")
train_env.close()
eval_env.close()
print("Trening zakończony. Model zapisany do models/rolling_ball_final.zip")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -4.58    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 4864     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -4.59    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 4847     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 4000     |
# ---------------------------------
# Eval num_timesteps=5000, episode_reward=1.37 +/- 15.83
# Episode length: 486.60 +/- 40.20
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 487      |
# |    mean_reward     | 1.37     |
# | time/              |          |
# |    total_timesteps | 5000     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -4.54    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 373      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 6000     |
# | train/             |          |
# |    actor_loss      | -0.819   |
# |    critic_loss     | 0.000282 |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 999      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 497      |
# |    ep_rew_mean     | -0.569   |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 245      |
# |    time_elapsed    | 32       |
# |    total_timesteps | 7954     |
# | train/             |          |
# |    actor_loss      | -1.91    |
# |    critic_loss     | 0.00041  |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2953     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 479      |
# |    ep_rew_mean     | 7.03     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 203      |
# |    time_elapsed    | 47       |
# |    total_timesteps | 9574     |
# | train/             |          |
# |    actor_loss      | -2.96    |
# |    critic_loss     | 0.0177   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4573     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=41.66 +/- 21.24
# Episode length: 261.80 +/- 160.73
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 262      |
# |    mean_reward     | 41.7     |
# | time/              |          |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | -3.14    |
# |    critic_loss     | 0.0278   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4999     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 469      |
# |    ep_rew_mean     | 10.1     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 174      |
# |    time_elapsed    | 64       |
# |    total_timesteps | 11266    |
# | train/             |          |
# |    actor_loss      | -4.21    |
# |    critic_loss     | 0.0687   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6265     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 454      |
# |    ep_rew_mean     | 12.6     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 162      |
# |    time_elapsed    | 78       |
# |    total_timesteps | 12714    |
# | train/             |          |
# |    actor_loss      | -5.56    |
# |    critic_loss     | 0.514    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7713     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 426      |
# |    ep_rew_mean     | 15.9     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 156      |
# |    time_elapsed    | 87       |
# |    total_timesteps | 13631    |
# | train/             |          |
# |    actor_loss      | -6.59    |
# |    critic_loss     | 4.74     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8630     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 416      |
# |    ep_rew_mean     | 16.9     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 152      |
# |    time_elapsed    | 98       |
# |    total_timesteps | 14977    |
# | train/             |          |
# |    actor_loss      | -6.74    |
# |    critic_loss     | 0.274    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9976     |
# ---------------------------------
# Eval num_timesteps=15000, episode_reward=30.74 +/- 27.12
# Episode length: 308.50 +/- 194.41
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 308      |
# |    mean_reward     | 30.7     |
# | time/              |          |
# |    total_timesteps | 15000    |
# | train/             |          |
# |    actor_loss      | -7.43    |
# |    critic_loss     | 0.544    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 399      |
# |    ep_rew_mean     | 19.2     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 143      |
# |    time_elapsed    | 110      |
# |    total_timesteps | 15961    |
# | train/             |          |
# |    actor_loss      | -8.35    |
# |    critic_loss     | 0.373    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10960    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 392      |
# |    ep_rew_mean     | 21       |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 141      |
# |    time_elapsed    | 121      |
# |    total_timesteps | 17268    |
# | train/             |          |
# |    actor_loss      | -9.46    |
# |    critic_loss     | 0.19     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12267    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 384      |
# |    ep_rew_mean     | 21.4     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 138      |
# |    time_elapsed    | 132      |
# |    total_timesteps | 18414    |
# | train/             |          |
# |    actor_loss      | -10.3    |
# |    critic_loss     | 0.241    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13413    |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=13.64 +/- 25.43
# Episode length: 398.60 +/- 165.49
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 399      |
# |    mean_reward     | 13.6     |
# | time/              |          |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -9.76    |
# |    critic_loss     | 0.135    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 385      |
# |    ep_rew_mean     | 20.7     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 132      |
# |    time_elapsed    | 151      |
# |    total_timesteps | 20028    |
# | train/             |          |
# |    actor_loss      | -10.5    |
# |    critic_loss     | 0.175    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15027    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 369      |
# |    ep_rew_mean     | 23       |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 131      |
# |    time_elapsed    | 157      |
# |    total_timesteps | 20671    |
# | train/             |          |
# |    actor_loss      | -11.7    |
# |    critic_loss     | 0.261    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15670    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 368      |
# |    ep_rew_mean     | 23.1     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 129      |
# |    time_elapsed    | 170      |
# |    total_timesteps | 22078    |
# | train/             |          |
# |    actor_loss      | -10.6    |
# |    critic_loss     | 0.101    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17077    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 366      |
# |    ep_rew_mean     | 23.3     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 127      |
# |    time_elapsed    | 183      |
# |    total_timesteps | 23396    |
# | train/             |          |
# |    actor_loss      | -12.6    |
# |    critic_loss     | 0.0837   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18395    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 354      |
# |    ep_rew_mean     | 25       |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 128      |
# |    time_elapsed    | 188      |
# |    total_timesteps | 24106    |
# | train/             |          |
# |    actor_loss      | -12.2    |
# |    critic_loss     | 0.0786   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19105    |
# ---------------------------------
# Eval num_timesteps=25000, episode_reward=36.50 +/- 25.08
# Episode length: 289.60 +/- 152.59
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 290      |
# |    mean_reward     | 36.5     |
# | time/              |          |
# |    total_timesteps | 25000    |
# | train/             |          |
# |    actor_loss      | -12.5    |
# |    critic_loss     | 0.0722   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 352      |
# |    ep_rew_mean     | 24.9     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 124      |
# |    time_elapsed    | 202      |
# |    total_timesteps | 25312    |
# | train/             |          |
# |    actor_loss      | -12.1    |
# |    critic_loss     | 0.0984   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20311    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 353      |
# |    ep_rew_mean     | 25.8     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 124      |
# |    time_elapsed    | 214      |
# |    total_timesteps | 26806    |
# | train/             |          |
# |    actor_loss      | -12      |
# |    critic_loss     | 0.104    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21805    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 360      |
# |    ep_rew_mean     | 24.4     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 123      |
# |    time_elapsed    | 232      |
# |    total_timesteps | 28806    |
# | train/             |          |
# |    actor_loss      | -13.2    |
# |    critic_loss     | 0.108    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23805    |
# ---------------------------------
# Eval num_timesteps=30000, episode_reward=9.75 +/- 22.82
# Episode length: 428.10 +/- 143.95
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 428      |
# |    mean_reward     | 9.75     |
# | time/              |          |
# |    total_timesteps | 30000    |
# | train/             |          |
# |    actor_loss      | -13.8    |
# |    critic_loss     | 0.0683   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 362      |
# |    ep_rew_mean     | 23.8     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 121      |
# |    time_elapsed    | 250      |
# |    total_timesteps | 30414    |
# | train/             |          |
# |    actor_loss      | -13.4    |
# |    critic_loss     | 0.0588   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25413    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 359      |
# |    ep_rew_mean     | 23.9     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 121      |
# |    time_elapsed    | 261      |
# |    total_timesteps | 31631    |
# | train/             |          |
# |    actor_loss      | -14.5    |
# |    critic_loss     | 0.169    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 26630    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 357      |
# |    ep_rew_mean     | 24       |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 120      |
# |    time_elapsed    | 272      |
# |    total_timesteps | 32845    |
# | train/             |          |
# |    actor_loss      | -14.5    |
# |    critic_loss     | 0.0547   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27844    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 359      |
# |    ep_rew_mean     | 24.2     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 120      |
# |    time_elapsed    | 285      |
# |    total_timesteps | 34490    |
# | train/             |          |
# |    actor_loss      | -15.6    |
# |    critic_loss     | 0.0789   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 29489    |
# ---------------------------------
# Eval num_timesteps=35000, episode_reward=26.49 +/- 28.07
# Episode length: 326.90 +/- 191.82
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 327      |
# |    mean_reward     | 26.5     |
# | time/              |          |
# |    total_timesteps | 35000    |
# | train/             |          |
# |    actor_loss      | -16.9    |
# |    critic_loss     | 0.216    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 29999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 356      |
# |    ep_rew_mean     | 24.2     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 118      |
# |    time_elapsed    | 299      |
# |    total_timesteps | 35596    |
# | train/             |          |
# |    actor_loss      | -15      |
# |    critic_loss     | 0.219    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 30595    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 347      |
# |    ep_rew_mean     | 25.5     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 119      |
# |    time_elapsed    | 308      |
# |    total_timesteps | 36700    |
# | train/             |          |
# |    actor_loss      | -14.7    |
# |    critic_loss     | 0.181    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 337      |
# |    ep_rew_mean     | 27.2     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 118      |
# |    time_elapsed    | 316      |
# |    total_timesteps | 37672    |
# | train/             |          |
# |    actor_loss      | -15.1    |
# |    critic_loss     | 0.31     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 32671    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 333      |
# |    ep_rew_mean     | 27.9     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 118      |
# |    time_elapsed    | 332      |
# |    total_timesteps | 39289    |
# | train/             |          |
# |    actor_loss      | -15.9    |
# |    critic_loss     | 0.0961   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 34288    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 320      |
# |    ep_rew_mean     | 29.6     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 118      |
# |    time_elapsed    | 336      |
# |    total_timesteps | 39911    |
# | train/             |          |
# |    actor_loss      | -15.8    |
# |    critic_loss     | 0.179    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 34910    |
# ---------------------------------
# Eval num_timesteps=40000, episode_reward=31.38 +/- 28.88
# Episode length: 340.90 +/- 176.16
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 341      |
# |    mean_reward     | 31.4     |
# | time/              |          |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -16.6    |
# |    critic_loss     | 0.108    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 34999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 311      |
# |    ep_rew_mean     | 29.7     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 117      |
# |    time_elapsed    | 346      |
# |    total_timesteps | 40711    |
# | train/             |          |
# |    actor_loss      | -17.9    |
# |    critic_loss     | 0.131    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 35710    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 310      |
# |    ep_rew_mean     | 29.1     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 117      |
# |    time_elapsed    | 361      |
# |    total_timesteps | 42281    |
# | train/             |          |
# |    actor_loss      | -15.7    |
# |    critic_loss     | 0.147    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 37280    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 312      |
# |    ep_rew_mean     | 29.1     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 117      |
# |    time_elapsed    | 373      |
# |    total_timesteps | 43874    |
# | train/             |          |
# |    actor_loss      | -14.8    |
# |    critic_loss     | 0.123    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 38873    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 311      |
# |    ep_rew_mean     | 29.3     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 117      |
# |    time_elapsed    | 381      |
# |    total_timesteps | 44772    |
# | train/             |          |
# |    actor_loss      | -15.7    |
# |    critic_loss     | 0.138    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39771    |
# ---------------------------------
# Eval num_timesteps=45000, episode_reward=38.79 +/- 25.67
# Episode length: 257.50 +/- 175.67
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 258      |
# |    mean_reward     | 38.8     |
# | time/              |          |
# |    total_timesteps | 45000    |
# | train/             |          |
# |    actor_loss      | -16.7    |
# |    critic_loss     | 0.0524   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 312      |
# |    ep_rew_mean     | 29.3     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 117      |
# |    time_elapsed    | 394      |
# |    total_timesteps | 46165    |
# | train/             |          |
# |    actor_loss      | -15.7    |
# |    critic_loss     | 0.0697   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 41164    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 314      |
# |    ep_rew_mean     | 29.3     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 116      |
# |    time_elapsed    | 405      |
# |    total_timesteps | 47363    |
# | train/             |          |
# |    actor_loss      | -15.7    |
# |    critic_loss     | 0.118    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 42362    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 313      |
# |    ep_rew_mean     | 28.8     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 116      |
# |    time_elapsed    | 417      |
# |    total_timesteps | 48601    |
# | train/             |          |
# |    actor_loss      | -15.7    |
# |    critic_loss     | 0.209    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43600    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 310      |
# |    ep_rew_mean     | 29.4     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 116      |
# |    time_elapsed    | 425      |
# |    total_timesteps | 49445    |
# | train/             |          |
# |    actor_loss      | -15.2    |
# |    critic_loss     | 0.236    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 44444    |
# ---------------------------------
# Eval num_timesteps=50000, episode_reward=36.91 +/- 25.63
# Episode length: 228.70 +/- 185.66
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 229      |
# |    mean_reward     | 36.9     |
# | time/              |          |
# |    total_timesteps | 50000    |
# | train/             |          |
# |    actor_loss      | -15.8    |
# |    critic_loss     | 0.0851   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 44999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 310      |
# |    ep_rew_mean     | 29.9     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 115      |
# |    time_elapsed    | 440      |
# |    total_timesteps | 50997    |
# | train/             |          |
# |    actor_loss      | -15.9    |
# |    critic_loss     | 0.0743   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 45996    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 312      |
# |    ep_rew_mean     | 29.9     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 115      |
# |    time_elapsed    | 448      |
# |    total_timesteps | 51839    |
# | train/             |          |
# |    actor_loss      | -16.3    |
# |    critic_loss     | 0.0988   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 46838    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 31       |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 115      |
# |    time_elapsed    | 450      |
# |    total_timesteps | 52070    |
# | train/             |          |
# |    actor_loss      | -15.7    |
# |    critic_loss     | 0.0322   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47069    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 293      |
# |    ep_rew_mean     | 32.2     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 115      |
# |    time_elapsed    | 454      |
# |    total_timesteps | 52702    |
# | train/             |          |
# |    actor_loss      | -15.6    |
# |    critic_loss     | 0.045    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47701    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 295      |
# |    ep_rew_mean     | 31.7     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 115      |
# |    time_elapsed    | 462      |
# |    total_timesteps | 53569    |
# | train/             |          |
# |    actor_loss      | -16.9    |
# |    critic_loss     | 0.197    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 48568    |
# ---------------------------------
# Eval num_timesteps=55000, episode_reward=19.83 +/- 27.63
# Episode length: 365.40 +/- 193.71
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 365      |
# |    mean_reward     | 19.8     |
# | time/              |          |
# |    total_timesteps | 55000    |
# | train/             |          |
# |    actor_loss      | -16.3    |
# |    critic_loss     | 0.166    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 299      |
# |    ep_rew_mean     | 31.3     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 114      |
# |    time_elapsed    | 482      |
# |    total_timesteps | 55251    |
# | train/             |          |
# |    actor_loss      | -16.2    |
# |    critic_loss     | 0.151    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 50250    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 296      |
# |    ep_rew_mean     | 30.6     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 114      |
# |    time_elapsed    | 490      |
# |    total_timesteps | 56393    |
# | train/             |          |
# |    actor_loss      | -15      |
# |    critic_loss     | 0.328    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 51392    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 290      |
# |    ep_rew_mean     | 31.8     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 114      |
# |    time_elapsed    | 503      |
# |    total_timesteps | 57815    |
# | train/             |          |
# |    actor_loss      | -15      |
# |    critic_loss     | 0.109    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 52814    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 279      |
# |    ep_rew_mean     | 33.5     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 114      |
# |    time_elapsed    | 507      |
# |    total_timesteps | 58306    |
# | train/             |          |
# |    actor_loss      | -16.7    |
# |    critic_loss     | 0.139    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 53305    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 279      |
# |    ep_rew_mean     | 34       |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 115      |
# |    time_elapsed    | 516      |
# |    total_timesteps | 59526    |
# | train/             |          |
# |    actor_loss      | -17      |
# |    critic_loss     | 0.22     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 54525    |
# ---------------------------------
# Eval num_timesteps=60000, episode_reward=26.51 +/- 27.53
# Episode length: 335.80 +/- 189.81
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 336      |
# |    mean_reward     | 26.5     |
# | time/              |          |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | -15.6    |
# |    critic_loss     | 0.0404   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 54999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 275      |
# |    ep_rew_mean     | 34.5     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 114      |
# |    time_elapsed    | 526      |
# |    total_timesteps | 60365    |
# | train/             |          |
# |    actor_loss      | -17      |
# |    critic_loss     | 0.152    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 55364    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 266      |
# |    ep_rew_mean     | 35.6     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 114      |
# |    time_elapsed    | 532      |
# |    total_timesteps | 61042    |
# | train/             |          |
# |    actor_loss      | -16.3    |
# |    critic_loss     | 0.0841   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 56041    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 262      |
# |    ep_rew_mean     | 36.2     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 114      |
# |    time_elapsed    | 539      |
# |    total_timesteps | 61815    |
# | train/             |          |
# |    actor_loss      | -16.5    |
# |    critic_loss     | 0.156    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 56814    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 259      |
# |    ep_rew_mean     | 36.7     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 114      |
# |    time_elapsed    | 545      |
# |    total_timesteps | 62567    |
# | train/             |          |
# |    actor_loss      | -16.3    |
# |    critic_loss     | 0.171    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 57566    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 253      |
# |    ep_rew_mean     | 37.3     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 115      |
# |    time_elapsed    | 547      |
# |    total_timesteps | 63019    |
# | train/             |          |
# |    actor_loss      | -16.4    |
# |    critic_loss     | 0.162    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 58018    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 246      |
# |    ep_rew_mean     | 38.4     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 114      |
# |    time_elapsed    | 555      |
# |    total_timesteps | 63908    |
# | train/             |          |
# |    actor_loss      | -16.3    |
# |    critic_loss     | 0.13     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 58907    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 246      |
# |    ep_rew_mean     | 38.4     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 114      |
# |    time_elapsed    | 561      |
# |    total_timesteps | 64485    |
# | train/             |          |
# |    actor_loss      | -16.2    |
# |    critic_loss     | 0.147    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 59484    |
# ---------------------------------
# Eval num_timesteps=65000, episode_reward=53.69 +/- 1.85
# Episode length: 180.60 +/- 124.89
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 181      |
# |    mean_reward     | 53.7     |
# | time/              |          |
# |    total_timesteps | 65000    |
# | train/             |          |
# |    actor_loss      | -16.8    |
# |    critic_loss     | 0.0798   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 59999    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 245      |
# |    ep_rew_mean     | 39       |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 114      |
# |    time_elapsed    | 570      |
# |    total_timesteps | 65218    |
# | train/             |          |
# |    actor_loss      | -16.7    |
# |    critic_loss     | 0.125    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 60217    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 243      |
# |    ep_rew_mean     | 39.5     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 114      |
# |    time_elapsed    | 581      |
# |    total_timesteps | 66608    |
# | train/             |          |
# |    actor_loss      | -16.8    |
# |    critic_loss     | 0.0756   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 61607    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 236      |
# |    ep_rew_mean     | 40.5     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 114      |
# |    time_elapsed    | 588      |
# |    total_timesteps | 67498    |
# | train/             |          |
# |    actor_loss      | -15.6    |
# |    critic_loss     | 0.12     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 62497    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 236      |
# |    ep_rew_mean     | 41       |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 114      |
# |    time_elapsed    | 596      |
# |    total_timesteps | 68339    |
# | train/             |          |
# |    actor_loss      | -15.9    |
# |    critic_loss     | 0.116    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 63338    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 227      |
# |    ep_rew_mean     | 42.1     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 114      |
# |    time_elapsed    | 600      |
# |    total_timesteps | 68872    |
# | train/             |          |
# |    actor_loss      | -18.2    |
# |    critic_loss     | 0.11     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 63871    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 221      |
# |    ep_rew_mean     | 42.6     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 114      |
# |    time_elapsed    | 606      |
# |    total_timesteps | 69471    |
# | train/             |          |
# |    actor_loss      | -17.3    |
# |    critic_loss     | 0.199    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 64470    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 214      |
# |    ep_rew_mean     | 43.8     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 114      |
# |    time_elapsed    | 608      |
# |    total_timesteps | 69979    |
# | train/             |          |
# |    actor_loss      | -16.3    |
# |    critic_loss     | 0.0705   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 64978    |
# ---------------------------------
# Eval num_timesteps=70000, episode_reward=56.39 +/- 1.10
# Episode length: 229.90 +/- 123.31
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 230      |
# |    mean_reward     | 56.4     |
# | time/              |          |
# |    total_timesteps | 70000    |
# | train/             |          |
# |    actor_loss      | -16.1    |
# |    critic_loss     | 0.12     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 64999    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 218      |
# |    ep_rew_mean     | 43.8     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 114      |
# |    time_elapsed    | 621      |
# |    total_timesteps | 71232    |
# | train/             |          |
# |    actor_loss      | -15.4    |
# |    critic_loss     | 0.0981   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 66231    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 216      |
# |    ep_rew_mean     | 44.3     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 114      |
# |    time_elapsed    | 634      |
# |    total_timesteps | 72580    |
# | train/             |          |
# |    actor_loss      | -16.1    |
# |    critic_loss     | 0.147    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 67579    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 214      |
# |    ep_rew_mean     | 44.4     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 114      |
# |    time_elapsed    | 639      |
# |    total_timesteps | 73245    |
# | train/             |          |
# |    actor_loss      | -16.6    |
# |    critic_loss     | 0.0785   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 68244    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 219      |
# |    ep_rew_mean     | 44.4     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 114      |
# |    time_elapsed    | 645      |
# |    total_timesteps | 73927    |
# | train/             |          |
# |    actor_loss      | -15.8    |
# |    critic_loss     | 0.115    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 68926    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 221      |
# |    ep_rew_mean     | 43.9     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 114      |
# |    time_elapsed    | 654      |
# |    total_timesteps | 74794    |
# | train/             |          |
# |    actor_loss      | -16.9    |
# |    critic_loss     | 0.128    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 69793    |
# ---------------------------------
# Eval num_timesteps=75000, episode_reward=47.97 +/- 17.67
# Episode length: 173.50 +/- 139.05
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 174      |
# |    mean_reward     | 48       |
# | time/              |          |
# |    total_timesteps | 75000    |
# | train/             |          |
# |    actor_loss      | -16.2    |
# |    critic_loss     | 0.0755   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 69999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 224      |
# |    ep_rew_mean     | 43.9     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 114      |
# |    time_elapsed    | 666      |
# |    total_timesteps | 75988    |
# | train/             |          |
# |    actor_loss      | -16.3    |
# |    critic_loss     | 0.0661   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 70987    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 216      |
# |    ep_rew_mean     | 45       |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 114      |
# |    time_elapsed    | 672      |
# |    total_timesteps | 76811    |
# | train/             |          |
# |    actor_loss      | -17.6    |
# |    critic_loss     | 0.0656   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 71810    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 212      |
# |    ep_rew_mean     | 46.1     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 114      |
# |    time_elapsed    | 679      |
# |    total_timesteps | 77544    |
# | train/             |          |
# |    actor_loss      | -17.4    |
# |    critic_loss     | 0.0559   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 72543    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | 47.1     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 114      |
# |    time_elapsed    | 682      |
# |    total_timesteps | 77786    |
# | train/             |          |
# |    actor_loss      | -16.8    |
# |    critic_loss     | 0.0607   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 72785    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 205      |
# |    ep_rew_mean     | 46.6     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 113      |
# |    time_elapsed    | 692      |
# |    total_timesteps | 78779    |
# | train/             |          |
# |    actor_loss      | -18.2    |
# |    critic_loss     | 0.125    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 73778    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 201      |
# |    ep_rew_mean     | 46.5     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 114      |
# |    time_elapsed    | 698      |
# |    total_timesteps | 79657    |
# | train/             |          |
# |    actor_loss      | -17.9    |
# |    critic_loss     | 0.0379   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 74656    |
# ---------------------------------
# Eval num_timesteps=80000, episode_reward=37.02 +/- 27.02
# Episode length: 281.60 +/- 168.40
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 282      |
# |    mean_reward     | 37       |
# | time/              |          |
# |    total_timesteps | 80000    |
# | train/             |          |
# |    actor_loss      | -18.5    |
# |    critic_loss     | 0.0948   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 74999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 197      |
# |    ep_rew_mean     | 47.1     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 113      |
# |    time_elapsed    | 705      |
# |    total_timesteps | 80054    |
# | train/             |          |
# |    actor_loss      | -16.2    |
# |    critic_loss     | 0.0724   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 75053    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 201      |
# |    ep_rew_mean     | 46.6     |
# | time/              |          |
# ...
# |    critic_loss     | 0.0501   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 479999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 155      |
# |    ep_rew_mean     | 54.2     |
# | time/              |          |
# |    episodes        | 2768     |
# |    fps             | 113      |
# |    time_elapsed    | 4285     |
# |    total_timesteps | 485332   |
# | train/             |          |
# |    actor_loss      | -20.5    |
# |    critic_loss     | 0.0717   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 480331   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 153      |
# |    ep_rew_mean     | 54.1     |
# | time/              |          |
# |    episodes        | 2772     |
# |    fps             | 113      |
# |    time_elapsed    | 4288     |
# |    total_timesteps | 485729   |
# | train/             |          |
# |    actor_loss      | -22      |
# |    critic_loss     | 0.0872   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 480728   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 153      |
# |    ep_rew_mean     | 54.1     |
# | time/              |          |
# |    episodes        | 2776     |
# |    fps             | 113      |
# |    time_elapsed    | 4293     |
# |    total_timesteps | 486246   |
# | train/             |          |
# |    actor_loss      | -23.7    |
# |    critic_loss     | 0.0656   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 481245   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 152      |
# |    ep_rew_mean     | 54.2     |
# | time/              |          |
# |    episodes        | 2780     |
# |    fps             | 113      |
# |    time_elapsed    | 4296     |
# |    total_timesteps | 486617   |
# | train/             |          |
# |    actor_loss      | -23.7    |
# |    critic_loss     | 0.0852   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 481616   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 153      |
# |    ep_rew_mean     | 54.2     |
# | time/              |          |
# |    episodes        | 2784     |
# |    fps             | 113      |
# |    time_elapsed    | 4301     |
# |    total_timesteps | 487532   |
# | train/             |          |
# |    actor_loss      | -21      |
# |    critic_loss     | 0.19     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 482531   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 150      |
# |    ep_rew_mean     | 54.1     |
# | time/              |          |
# |    episodes        | 2788     |
# |    fps             | 113      |
# |    time_elapsed    | 4306     |
# |    total_timesteps | 488167   |
# | train/             |          |
# |    actor_loss      | -22.3    |
# |    critic_loss     | 0.0555   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 483166   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 149      |
# |    ep_rew_mean     | 54.1     |
# | time/              |          |
# |    episodes        | 2792     |
# |    fps             | 113      |
# |    time_elapsed    | 4309     |
# |    total_timesteps | 488527   |
# | train/             |          |
# |    actor_loss      | -22.5    |
# |    critic_loss     | 0.0695   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 483526   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 154      |
# |    ep_rew_mean     | 54.2     |
# | time/              |          |
# |    episodes        | 2796     |
# |    fps             | 113      |
# |    time_elapsed    | 4317     |
# |    total_timesteps | 489403   |
# | train/             |          |
# |    actor_loss      | -21.3    |
# |    critic_loss     | 0.0544   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 484402   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 155      |
# |    ep_rew_mean     | 54.2     |
# | time/              |          |
# |    episodes        | 2800     |
# |    fps             | 113      |
# |    time_elapsed    | 4320     |
# |    total_timesteps | 489849   |
# | train/             |          |
# |    actor_loss      | -22.3    |
# |    critic_loss     | 0.0714   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 484848   |
# ---------------------------------
# Eval num_timesteps=490000, episode_reward=56.16 +/- 2.38
# Episode length: 177.50 +/- 84.78
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 178      |
# |    mean_reward     | 56.2     |
# | time/              |          |
# |    total_timesteps | 490000   |
# | train/             |          |
# |    actor_loss      | -22.7    |
# |    critic_loss     | 0.0743   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 484999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 155      |
# |    ep_rew_mean     | 54.2     |
# | time/              |          |
# |    episodes        | 2804     |
# |    fps             | 113      |
# |    time_elapsed    | 4325     |
# |    total_timesteps | 490272   |
# | train/             |          |
# |    actor_loss      | -22.6    |
# |    critic_loss     | 0.0737   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 485271   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 153      |
# |    ep_rew_mean     | 54.3     |
# | time/              |          |
# |    episodes        | 2808     |
# |    fps             | 113      |
# |    time_elapsed    | 4330     |
# |    total_timesteps | 490888   |
# | train/             |          |
# |    actor_loss      | -20.9    |
# |    critic_loss     | 0.158    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 485887   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 145      |
# |    ep_rew_mean     | 54.9     |
# | time/              |          |
# |    episodes        | 2812     |
# |    fps             | 113      |
# |    time_elapsed    | 4331     |
# |    total_timesteps | 491228   |
# | train/             |          |
# |    actor_loss      | -23      |
# |    critic_loss     | 0.1      |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 486227   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 145      |
# |    ep_rew_mean     | 54.9     |
# | time/              |          |
# |    episodes        | 2816     |
# |    fps             | 113      |
# |    time_elapsed    | 4336     |
# |    total_timesteps | 491784   |
# | train/             |          |
# |    actor_loss      | -22.8    |
# |    critic_loss     | 0.0827   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 486783   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 140      |
# |    ep_rew_mean     | 54.8     |
# | time/              |          |
# |    episodes        | 2820     |
# |    fps             | 113      |
# |    time_elapsed    | 4339     |
# |    total_timesteps | 492201   |
# | train/             |          |
# |    actor_loss      | -22.8    |
# |    critic_loss     | 0.0461   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 487200   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 143      |
# |    ep_rew_mean     | 54.9     |
# | time/              |          |
# |    episodes        | 2824     |
# |    fps             | 113      |
# |    time_elapsed    | 4345     |
# |    total_timesteps | 492910   |
# | train/             |          |
# |    actor_loss      | -22.2    |
# |    critic_loss     | 0.116    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 487909   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 143      |
# |    ep_rew_mean     | 54.9     |
# | time/              |          |
# |    episodes        | 2828     |
# |    fps             | 113      |
# |    time_elapsed    | 4351     |
# |    total_timesteps | 493751   |
# | train/             |          |
# |    actor_loss      | -22.1    |
# |    critic_loss     | 0.134    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 488750   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | 54.9     |
# | time/              |          |
# |    episodes        | 2832     |
# |    fps             | 113      |
# |    time_elapsed    | 4355     |
# |    total_timesteps | 494242   |
# | train/             |          |
# |    actor_loss      | -23      |
# |    critic_loss     | 0.0922   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 489241   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 142      |
# |    ep_rew_mean     | 54.9     |
# | time/              |          |
# |    episodes        | 2836     |
# |    fps             | 113      |
# |    time_elapsed    | 4360     |
# |    total_timesteps | 494799   |
# | train/             |          |
# |    actor_loss      | -22.9    |
# |    critic_loss     | 0.0613   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 489798   |
# ---------------------------------
# Eval num_timesteps=495000, episode_reward=54.14 +/- 1.85
# Episode length: 100.70 +/- 44.81
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 101      |
# |    mean_reward     | 54.1     |
# | time/              |          |
# |    total_timesteps | 495000   |
# | train/             |          |
# |    actor_loss      | -22.8    |
# |    critic_loss     | 0.135    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 489999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 143      |
# |    ep_rew_mean     | 54.9     |
# | time/              |          |
# |    episodes        | 2840     |
# |    fps             | 113      |
# |    time_elapsed    | 4365     |
# |    total_timesteps | 495583   |
# | train/             |          |
# |    actor_loss      | -22.8    |
# |    critic_loss     | 0.0813   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 490582   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 140      |
# |    ep_rew_mean     | 54.8     |
# | time/              |          |
# |    episodes        | 2844     |
# |    fps             | 113      |
# |    time_elapsed    | 4369     |
# |    total_timesteps | 496099   |
# | train/             |          |
# |    actor_loss      | -22.6    |
# |    critic_loss     | 0.14     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 491098   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 141      |
# |    ep_rew_mean     | 54.2     |
# | time/              |          |
# |    episodes        | 2848     |
# |    fps             | 113      |
# |    time_elapsed    | 4376     |
# |    total_timesteps | 496887   |
# | train/             |          |
# |    actor_loss      | -22      |
# |    critic_loss     | 0.155    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 491886   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 143      |
# |    ep_rew_mean     | 54.2     |
# | time/              |          |
# |    episodes        | 2852     |
# |    fps             | 113      |
# |    time_elapsed    | 4381     |
# |    total_timesteps | 497424   |
# | train/             |          |
# |    actor_loss      | -22.6    |
# |    critic_loss     | 0.0463   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 492423   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 147      |
# |    ep_rew_mean     | 54.2     |
# | time/              |          |
# |    episodes        | 2856     |
# |    fps             | 113      |
# |    time_elapsed    | 4389     |
# |    total_timesteps | 498264   |
# | train/             |          |
# |    actor_loss      | -22.6    |
# |    critic_loss     | 0.0728   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 493263   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 146      |
# |    ep_rew_mean     | 54.2     |
# | time/              |          |
# |    episodes        | 2860     |
# |    fps             | 113      |
# |    time_elapsed    | 4392     |
# |    total_timesteps | 498644   |
# | train/             |          |
# |    actor_loss      | -23.1    |
# |    critic_loss     | 0.0595   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 493643   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 145      |
# |    ep_rew_mean     | 54.3     |
# | time/              |          |
# |    episodes        | 2864     |
# |    fps             | 113      |
# |    time_elapsed    | 4395     |
# |    total_timesteps | 499212   |
# | train/             |          |
# |    actor_loss      | -22.9    |
# |    critic_loss     | 0.0796   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 494211   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 144      |
# |    ep_rew_mean     | 54.2     |
# | time/              |          |
# |    episodes        | 2868     |
# |    fps             | 113      |
# |    time_elapsed    | 4399     |
# |    total_timesteps | 499725   |
# | train/             |          |
# |    actor_loss      | -22      |
# |    critic_loss     | 0.0755   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 494724   |
# ---------------------------------
# Eval num_timesteps=500000, episode_reward=56.78 +/- 1.68
# Episode length: 172.30 +/- 57.57
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 172      |
# |    mean_reward     | 56.8     |
# | time/              |          |
# |    total_timesteps | 500000   |
# | train/             |          |
# |    actor_loss      | -22.9    |
# |    critic_loss     | 0.0729   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 494999   |
# ---------------------------------
# New best mean reward!
# Trening zakończony. Model zapisany do models/rolling_ball_final.zip

# %%
import matplotlib.pyplot as plt

evaluations  = np.load("logs/evaluations.npz")
timesteps    = evaluations["timesteps"]
mean_rewards = evaluations["results"].mean(axis=1)
std_rewards  = evaluations["results"].std(axis=1)

fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(timesteps, mean_rewards, color="steelblue", label="Średnia nagroda (10 epizodów)")
ax.fill_between(
    timesteps,
    mean_rewards - std_rewards,
    mean_rewards + std_rewards,
    alpha=0.25, color="steelblue",
)
ax.axhline(0, color="gray", linewidth=0.7, linestyle="--")
ax.set_xlabel("Kroki (timesteps)")
ax.set_ylabel("Nagroda epizodu")
ax.set_title("Krzywa uczenia – SAC – Rolling Ball Navigator")
ax.legend()
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig("training_curve.png", dpi=150)
plt.show()

# %% [markdown]
# ## 3. Ewaluacja
#
# Wczytujemy najlepszy model zapisany przez `EvalCallback` i uruchamiamy go deterministycznie na zbiorze epizodów ewaluacyjnych. Mierzymy skuteczność (odsetek epizodów zakończonych sukcesem), średnią nagrodę i średnią liczbę kroków potrzebnych do dotarcia do celu.

# %%
from stable_baselines3 import SAC

model = SAC.load("models/best_model")

N_EVAL = 30
successes  = 0
ep_rewards = []
ep_lengths = []

eval_env = RollingBallEnv()
for ep in range(N_EVAL):
    obs, _ = eval_env.reset(seed=ep)
    total_reward = 0.0
    while True:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = eval_env.step(action)
        total_reward += reward
        if terminated or truncated:
            if terminated:
                successes += 1
            ep_rewards.append(total_reward)
            ep_lengths.append(info["step"])
            break
eval_env.close()

print(f"Wyniki ewaluacji ({N_EVAL} epizodów):")
print(f"  Skuteczność (dotarcie do celu): {successes / N_EVAL * 100:.1f}%")
print(f"  Średnia nagroda:                {np.mean(ep_rewards):.2f} ± {np.std(ep_rewards):.2f}")
print(f"  Średnia liczba kroków:          {np.mean(ep_lengths):.1f} ± {np.std(ep_lengths):.1f}")
# Out:
# Wyniki ewaluacji (30 epizodów):
#   Skuteczność (dotarcie do celu): 100.0%
#   Średnia nagroda:                54.90 ± 1.56
#   Średnia liczba kroków:          123.3 ± 76.2

# %%
from PIL import Image as PILImage
from IPython.display import display, Image
from stable_baselines3 import SAC

model   = SAC.load("models/best_model")
rec_env = RollingBallEnv(render_mode="rgb_array")

obs, _ = rec_env.reset(seed=0)
frames = [rec_env.render()]
while True:
    action, _ = model.predict(obs, deterministic=True)
    obs, _, terminated, truncated, _ = rec_env.step(action)
    frames.append(rec_env.render())
    if terminated or truncated:
        break
rec_env.close()

pil_frames = [PILImage.fromarray(f).resize((300, 300)) for f in frames]
pil_frames[0].save(
    "episode.gif",
    save_all=True,
    append_images=pil_frames[1:],
    duration=33,
    loop=0,
)
print(f"Nagrany epizod: {len(frames)} klatek ({len(frames) / 30:.1f} s @ 30 fps)")
display(Image("episode.gif"))
# Out:
# Nagrany epizod: 149 klatek (5.0 s @ 30 fps)

# %%
# ── Tryb na żywo (pygame window) ─────────────────────────────────────────────
# Uruchom tę komórkę oddzielnie. Otwiera okno pygame z agentem grającym w czasie
# rzeczywistym. Zamknij okno lub przerwij kernel aby zakończyć.

from stable_baselines3 import SAC

model    = SAC.load("models/best_model")
live_env = RollingBallEnv(render_mode="human")

for episode in range(10):
    obs, _ = live_env.reset()
    while True:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, terminated, truncated, _ = live_env.step(action)
        if terminated or truncated:
            break

live_env.close()
