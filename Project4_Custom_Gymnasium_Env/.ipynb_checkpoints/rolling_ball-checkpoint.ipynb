# %% [markdown]
# # Rolling Ball Navigator
#
# Własne środowisko Gymnasium zaimplementowane na potrzeby Projektu 4 z przedmiotu Inteligencja Obliczeniowa.
#
# Kulka tocząca się po planszy musi dotrzeć do wyznaczonego celu, omijając statyczne przeszkody. Agent uczy się nawigacji wyłącznie na podstawie lokalnych obserwacji: prędkości, kierunku do celu i sensorów odległości (raycasting) — bez znajomości swojej pozycji absolutnej.

# %% [markdown]
# ## 1. Środowisko `RollingBallEnv`
#
# Środowisko spełnia standardowy interfejs Gymnasium (`reset`, `step`, `render`, `close`). Przestrzeń obserwacji jest ciągła (wektor 13 liczb `float32`), przestrzeń akcji jest ciągła (wektor 2 liczb `float32`).
#
# | Element | Opis |
# |---------|------|
# | Obserwacje | `[vel_x, vel_y, goal_dx, goal_dy, goal_dist, ray_0 … ray_7]` |
# | Akcje | `[fx, fy]` — siła przykładana do kulki w osi X i Y |
# | Koniec epizodu | Dotarcie do celu (`terminated`) lub przekroczenie limitu kroków (`truncated`) |

# %%
import math
import numpy as np
import gymnasium as gym
from gymnasium import spaces
import pygame

# ── World constants ────────────────────────────────────────────────────────────
WORLD_W      = 600.0
WORLD_H      = 600.0
BALL_RADIUS  = 12.0
GOAL_RADIUS  = 18.0
FRICTION     = 0.92
FORCE_SCALE  = 0.4           # terminal vel ≈ 5.0
V_MAX        = 8.0
MAX_STEPS    = 500           # shorter episodes → agent sees goal reward more often
RAY_MAX      = 500.0
DIAGONAL     = math.sqrt(WORLD_W ** 2 + WORLD_H ** 2)
RAY_ANGLES   = [0, 45, 90, 135, 180, 225, 270, 315]

# Static obstacle layout: (left_x, top_y, width, height)
OBSTACLES = [
    ( 80,  80,  80, 200),
    (280,  40,  80, 160),
    (440, 100, 100,  60),
    (140, 340, 160,  60),
    (350, 280,  60, 200),
    (460, 380,  90, 130),
]


class RollingBallEnv(gym.Env):
    """2-D physics environment: roll a ball to a goal while avoiding obstacles."""

    metadata = {"render_modes": ["human", "rgb_array"], "render_fps": 30}

    def __init__(self, render_mode=None):
        super().__init__()
        assert render_mode is None or render_mode in self.metadata["render_modes"]
        self.render_mode = render_mode
        self._window = None
        self._clock  = None

        # All observations are normalised to [-1, 1] or [0, 1]
        low  = np.array([-1., -1., -1., -1., 0.] + [0.] * 8, dtype=np.float32)
        high = np.array([ 1.,  1.,  1.,  1., 1.] + [1.] * 8, dtype=np.float32)
        self.observation_space = spaces.Box(low, high, dtype=np.float32)
        self.action_space = spaces.Box(
            np.array([-1.0, -1.0], dtype=np.float32),
            np.array([ 1.0,  1.0], dtype=np.float32),
            dtype=np.float32,
        )

        self._pos        = np.zeros(2, dtype=np.float32)
        self._vel        = np.zeros(2, dtype=np.float32)
        self._goal       = np.zeros(2, dtype=np.float32)
        self._step_count = 0

    # ── Gymnasium interface ────────────────────────────────────────────────────

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        while True:
            p = np.array([
                self.np_random.uniform(BALL_RADIUS, WORLD_W - BALL_RADIUS),
                self.np_random.uniform(BALL_RADIUS, WORLD_H - BALL_RADIUS),
            ], dtype=np.float32)
            if self._is_free(p, BALL_RADIUS):
                self._pos = p
                break

        while True:
            g = np.array([
                self.np_random.uniform(GOAL_RADIUS, WORLD_W - GOAL_RADIUS),
                self.np_random.uniform(GOAL_RADIUS, WORLD_H - GOAL_RADIUS),
            ], dtype=np.float32)
            if self._is_free(g, GOAL_RADIUS) and np.linalg.norm(g - self._pos) > 100.0:
                self._goal = g
                break

        self._vel        = np.zeros(2, dtype=np.float32)
        self._step_count = 0

        obs  = self._get_obs()
        info = self._get_info()
        if self.render_mode == "human":
            self._render_frame()
        return obs, info

    def step(self, action):
        action = np.clip(action, -1.0, 1.0).astype(np.float32)

        prev_dist = float(np.linalg.norm(self._pos - self._goal))

        self._vel  = np.clip(self._vel + action * FORCE_SCALE, -V_MAX, V_MAX)
        self._vel *= FRICTION
        self._pos += self._vel

        hit = self._resolve_walls()
        for obs_rect in OBSTACLES:
            if self._resolve_obstacle(obs_rect):
                hit = True

        self._step_count += 1

        dist       = float(np.linalg.norm(self._pos - self._goal))
        terminated = dist <= GOAL_RADIUS + BALL_RADIUS
        truncated  = self._step_count >= MAX_STEPS

        reward  = -0.01                       # step penalty
        reward += -0.1 if hit else 0.0        # collision penalty
        reward += 0.005 * (prev_dist - dist)  # dense shaping: reward getting closer
        if terminated:
            reward += 50.0

        obs  = self._get_obs()
        info = self._get_info()
        if self.render_mode == "human":
            self._render_frame()
        return obs, float(reward), terminated, truncated, info

    def render(self):
        if self.render_mode == "rgb_array":
            return self._render_frame()

    def close(self):
        if self._window is not None:
            pygame.display.quit()
            pygame.quit()
            self._window = None
            self._clock  = None

    # ── Physics helpers ────────────────────────────────────────────────────────

    def _is_free(self, pos: np.ndarray, radius: float) -> bool:
        if (
            pos[0] - radius < 0 or pos[0] + radius > WORLD_W
            or pos[1] - radius < 0 or pos[1] + radius > WORLD_H
        ):
            return False
        for ox, oy, ow, oh in OBSTACLES:
            cx = float(np.clip(pos[0], ox, ox + ow))
            cy = float(np.clip(pos[1], oy, oy + oh))
            if math.sqrt((pos[0] - cx) ** 2 + (pos[1] - cy) ** 2) < radius + 2.0:
                return False
        return True

    def _resolve_walls(self) -> bool:
        hit = False
        if self._pos[0] - BALL_RADIUS < 0:
            self._pos[0] = BALL_RADIUS
            self._vel[0] = abs(self._vel[0])
            hit = True
        elif self._pos[0] + BALL_RADIUS > WORLD_W:
            self._pos[0] = WORLD_W - BALL_RADIUS
            self._vel[0] = -abs(self._vel[0])
            hit = True
        if self._pos[1] - BALL_RADIUS < 0:
            self._pos[1] = BALL_RADIUS
            self._vel[1] = abs(self._vel[1])
            hit = True
        elif self._pos[1] + BALL_RADIUS > WORLD_H:
            self._pos[1] = WORLD_H - BALL_RADIUS
            self._vel[1] = -abs(self._vel[1])
            hit = True
        return hit

    def _resolve_obstacle(self, rect) -> bool:
        ox, oy, ow, oh = rect
        cx = float(np.clip(self._pos[0], ox, ox + ow))
        cy = float(np.clip(self._pos[1], oy, oy + oh))
        dx = self._pos[0] - cx
        dy = self._pos[1] - cy
        dist_sq = dx * dx + dy * dy

        if dist_sq >= BALL_RADIUS * BALL_RADIUS:
            return False

        dist = math.sqrt(dist_sq)
        nx, ny = (dx / dist, dy / dist) if dist > 1e-6 else (1.0, 0.0)

        overlap = BALL_RADIUS - dist
        self._pos[0] += nx * (overlap + 0.5)
        self._pos[1] += ny * (overlap + 0.5)

        dot = self._vel[0] * nx + self._vel[1] * ny
        if dot < 0:
            self._vel[0] -= 2.0 * dot * nx
            self._vel[1] -= 2.0 * dot * ny
        return True

    # ── Ray-sensor helpers ─────────────────────────────────────────────────────

    def _cast_ray(self, angle_deg: float) -> float:
        rad = math.radians(angle_deg)
        dx  =  math.cos(rad)
        dy  = -math.sin(rad)
        ox, oy = float(self._pos[0]), float(self._pos[1])

        t = RAY_MAX
        if dx > 1e-9:
            t = min(t, (WORLD_W - ox) / dx)
        elif dx < -1e-9:
            t = min(t, -ox / dx)
        if dy > 1e-9:
            t = min(t, (WORLD_H - oy) / dy)
        elif dy < -1e-9:
            t = min(t, -oy / dy)

        for obs_rect in OBSTACLES:
            t_obs = self._ray_aabb(ox, oy, dx, dy, obs_rect)
            if t_obs < t:
                t = t_obs

        return float(np.clip(t, 0.0, RAY_MAX))

    @staticmethod
    def _ray_aabb(ox: float, oy: float, dx: float, dy: float, rect) -> float:
        rx, ry, rw, rh = rect
        t_near, t_far = -1e30, 1e30

        if abs(dx) > 1e-9:
            tx1 = (rx      - ox) / dx
            tx2 = (rx + rw - ox) / dx
            t_near = max(t_near, min(tx1, tx2))
            t_far  = min(t_far,  max(tx1, tx2))
        elif ox < rx or ox > rx + rw:
            return RAY_MAX

        if abs(dy) > 1e-9:
            ty1 = (ry      - oy) / dy
            ty2 = (ry + rh - oy) / dy
            t_near = max(t_near, min(ty1, ty2))
            t_far  = min(t_far,  max(ty1, ty2))
        elif oy < ry or oy > ry + rh:
            return RAY_MAX

        if t_far < t_near or t_near <= 0.0:
            return RAY_MAX
        return float(np.clip(t_near, 0.0, RAY_MAX))

    # ── Observation / info ─────────────────────────────────────────────────────

    def _get_obs(self) -> np.ndarray:
        ddx = self._goal[0] - self._pos[0]
        ddy = self._goal[1] - self._pos[1]
        dist = math.sqrt(ddx * ddx + ddy * ddy)
        if dist > 1e-9:
            ndx =  ddx / dist
            ndy = -ddy / dist
        else:
            ndx = ndy = 0.0

        rays = [self._cast_ray(a) for a in RAY_ANGLES]
        return np.array([
            self._vel[0] / V_MAX,          # [-1, 1]
            self._vel[1] / V_MAX,          # [-1, 1]
            ndx,                           # [-1, 1]
            ndy,                           # [-1, 1]
            dist / DIAGONAL,               # [0,  1]
            *[r / RAY_MAX for r in rays],  # [0,  1]
        ], dtype=np.float32)

    def _get_info(self) -> dict:
        return {
            "distance_to_goal": float(np.linalg.norm(self._pos - self._goal)),
            "step": self._step_count,
        }

    # ── Rendering ──────────────────────────────────────────────────────────────

    def _render_frame(self):
        if not pygame.get_init():
            pygame.init()
        if self.render_mode == "human":
            if self._window is None:
                pygame.display.init()
                self._window = pygame.display.set_mode((int(WORLD_W), int(WORLD_H)))
                pygame.display.set_caption("Rolling Ball Navigator")
            if self._clock is None:
                self._clock = pygame.time.Clock()

        canvas = pygame.Surface((int(WORLD_W), int(WORLD_H)))
        canvas.fill((20, 20, 20))

        pygame.draw.rect(canvas, (220, 220, 220), (0, 0, int(WORLD_W), int(WORLD_H)), 3)

        for ox, oy, ow, oh in OBSTACLES:
            pygame.draw.rect(canvas, (110, 110, 110), (int(ox), int(oy), int(ow), int(oh)))

        obs_vec = self._get_obs()
        for i, angle_deg in enumerate(RAY_ANGLES):
            rad = math.radians(angle_deg)
            rdx =  math.cos(rad)
            rdy = -math.sin(rad)
            ray_len = float(obs_vec[5 + i]) * RAY_MAX   # denormalize for drawing
            ex = int(self._pos[0] + rdx * ray_len)
            ey = int(self._pos[1] + rdy * ray_len)
            pygame.draw.line(
                canvas, (180, 40, 40),
                (int(self._pos[0]), int(self._pos[1])), (ex, ey), 1,
            )

        pygame.draw.circle(
            canvas, (30, 210, 80),
            (int(self._goal[0]), int(self._goal[1])), int(GOAL_RADIUS),
        )
        pygame.draw.circle(
            canvas, (50, 130, 255),
            (int(self._pos[0]), int(self._pos[1])), int(BALL_RADIUS),
        )

        if self.render_mode == "human":
            self._window.blit(canvas, canvas.get_rect())
            pygame.event.pump()
            pygame.display.update()
            self._clock.tick(self.metadata["render_fps"])
        else:
            return np.transpose(
                np.array(pygame.surfarray.pixels3d(canvas)), axes=(1, 0, 2)
            )

# %% [markdown]
# ## 2. Trening agenta (SAC)
#
# Do treningu używamy algorytmu **Soft Actor-Critic (SAC)** z biblioteki `stable-baselines3`. SAC jest dedykowany do ciągłych przestrzeni akcji — maksymalizuje zarówno oczekiwaną nagrodę, jak i entropię polityki, co przekłada się na stabilność uczenia i dobre eksplorowanie środowiska.
#
# Środowisko treningowe nie używa trybu graficznego (`render_mode=None`), co zapewnia maksymalną szybkość. Postęp ewaluacji jest zapisywany do pliku `logs/evaluations.npz` i wizualizowany po zakończeniu treningu.

# %%
import os
from stable_baselines3 import SAC
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import EvalCallback

os.makedirs("models", exist_ok=True)
os.makedirs("logs",   exist_ok=True)

train_env = RollingBallEnv()
eval_env  = Monitor(RollingBallEnv())

model = SAC(
    "MlpPolicy",
    train_env,
    learning_rate=3e-4,
    buffer_size=300_000,
    learning_starts=5_000,
    batch_size=256,
    tau=0.005,
    gamma=0.99,
    ent_coef=0.1,        # fixed — prevents auto-tuning from inflating entropy
    verbose=1,
    seed=42,
)

eval_callback = EvalCallback(
    eval_env,
    best_model_save_path="models/",
    log_path="logs/",
    eval_freq=5_000,
    n_eval_episodes=10,
    deterministic=True,
    render=False,
)

model.learn(total_timesteps=500_000, callback=eval_callback)
model.save("models/rolling_ball_final")
train_env.close()
eval_env.close()
print("Trening zakończony. Model zapisany do models/rolling_ball_final.zip")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -5.22    |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 5053     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -5.15    |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 4987     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 4000     |
# ---------------------------------
# Eval num_timesteps=5000, episode_reward=-15.01 +/- 14.82
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | -15      |
# | time/              |          |
# |    total_timesteps | 5000     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -5.14    |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 463      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 6000     |
# | train/             |          |
# |    actor_loss      | -0.819   |
# |    critic_loss     | 0.000308 |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 999      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -5.11    |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 295      |
# |    time_elapsed    | 27       |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -1.9     |
# |    critic_loss     | 0.000436 |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2999     |
# ---------------------------------
# Eval num_timesteps=10000, episode_reward=-5.78 +/- 1.57
# Episode length: 500.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 500      |
# |    mean_reward     | -5.78    |
# | time/              |          |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | -2.89    |
# |    critic_loss     | 0.000511 |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4999     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -5       |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 219      |
# |    time_elapsed    | 45       |
# |    total_timesteps | 10000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -4.92    |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 195      |
# |    time_elapsed    | 61       |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -3.81    |
# |    critic_loss     | 0.000469 |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6999     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -4.9     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 185      |
# |    time_elapsed    | 75       |
# |    total_timesteps | 14000    |
# | train/             |          |
# |    actor_loss      | -4.63    |
# |    critic_loss     | 0.000331 |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8999     |
# ---------------------------------
# Eval num_timesteps=15000, episode_reward=5.05 +/- 20.86
# Episode length: 476.40 +/- 70.47
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 476      |
# |    mean_reward     | 5.05     |
# | time/              |          |
# |    total_timesteps | 15000    |
# | train/             |          |
# |    actor_loss      | -5.01    |
# |    critic_loss     | 0.000412 |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9999     |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -4.92    |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 168      |
# |    time_elapsed    | 94       |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -5.35    |
# |    critic_loss     | 0.000591 |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 500      |
# |    ep_rew_mean     | -4.89    |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 164      |
# |    time_elapsed    | 109      |
# |    total_timesteps | 18000    |
# | train/             |          |
# |    actor_loss      | -6.02    |
# |    critic_loss     | 0.000677 |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 494      |
# |    ep_rew_mean     | -2.31    |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 161      |
# |    time_elapsed    | 122      |
# |    total_timesteps | 19749    |
# | train/             |          |
# |    actor_loss      | -6.57    |
# |    critic_loss     | 0.00576  |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14748    |
# ---------------------------------
# Eval num_timesteps=20000, episode_reward=-1.46 +/- 16.77
# Episode length: 470.60 +/- 88.20
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 471      |
# |    mean_reward     | -1.46    |
# | time/              |          |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -6.67    |
# |    critic_loss     | 0.00415  |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 494      |
# |    ep_rew_mean     | -2.55    |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 155      |
# |    time_elapsed    | 139      |
# |    total_timesteps | 21749    |
# | train/             |          |
# |    actor_loss      | -7.15    |
# |    critic_loss     | 0.00436  |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16748    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 483      |
# |    ep_rew_mean     | -0.529   |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 153      |
# |    time_elapsed    | 150      |
# |    total_timesteps | 23163    |
# | train/             |          |
# |    actor_loss      | -7.48    |
# |    critic_loss     | 0.00556  |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18162    |
# ---------------------------------
# Eval num_timesteps=25000, episode_reward=3.79 +/- 23.05
# Episode length: 423.00 +/- 155.88
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 423      |
# |    mean_reward     | 3.79     |
# | time/              |          |
# |    total_timesteps | 25000    |
# | train/             |          |
# |    actor_loss      | -8       |
# |    critic_loss     | 0.0377   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 481      |
# |    ep_rew_mean     | 0.111    |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 150      |
# |    time_elapsed    | 166      |
# |    total_timesteps | 25001    |
# | train/             |          |
# |    actor_loss      | -8.1     |
# |    critic_loss     | 0.0175   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20000    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 478      |
# |    ep_rew_mean     | 0.675    |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 148      |
# |    time_elapsed    | 179      |
# |    total_timesteps | 26777    |
# | train/             |          |
# |    actor_loss      | -8.18    |
# |    critic_loss     | 0.0216   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21776    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 472      |
# |    ep_rew_mean     | 1.21     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 147      |
# |    time_elapsed    | 191      |
# |    total_timesteps | 28348    |
# | train/             |          |
# |    actor_loss      | -9.08    |
# |    critic_loss     | 4.02     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23347    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 468      |
# |    ep_rew_mean     | 1.63     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 147      |
# |    time_elapsed    | 202      |
# |    total_timesteps | 29929    |
# | train/             |          |
# |    actor_loss      | -9.5     |
# |    critic_loss     | 0.248    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24928    |
# ---------------------------------
# Eval num_timesteps=30000, episode_reward=-18.01 +/- 27.85
# Episode length: 461.00 +/- 117.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 461      |
# |    mean_reward     | -18      |
# | time/              |          |
# |    total_timesteps | 30000    |
# | train/             |          |
# |    actor_loss      | -9.39    |
# |    critic_loss     | 0.235    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 467      |
# |    ep_rew_mean     | 1.98     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 144      |
# |    time_elapsed    | 219      |
# |    total_timesteps | 31726    |
# | train/             |          |
# |    actor_loss      | -9.62    |
# |    critic_loss     | 0.144    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 26725    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 463      |
# |    ep_rew_mean     | 2.35     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 144      |
# |    time_elapsed    | 230      |
# |    total_timesteps | 33314    |
# | train/             |          |
# |    actor_loss      | -10.2    |
# |    critic_loss     | 0.0513   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 28313    |
# ---------------------------------
# Eval num_timesteps=35000, episode_reward=-10.29 +/- 24.02
# Episode length: 482.90 +/- 51.30
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 483      |
# |    mean_reward     | -10.3    |
# | time/              |          |
# |    total_timesteps | 35000    |
# | train/             |          |
# |    actor_loss      | -10.7    |
# |    critic_loss     | 3.54     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 29999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 465      |
# |    ep_rew_mean     | 1.92     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 141      |
# |    time_elapsed    | 250      |
# |    total_timesteps | 35314    |
# | train/             |          |
# |    actor_loss      | -9.63    |
# |    critic_loss     | 0.0547   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 30313    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 466      |
# |    ep_rew_mean     | 1.59     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 141      |
# |    time_elapsed    | 264      |
# |    total_timesteps | 37314    |
# | train/             |          |
# |    actor_loss      | -10.1    |
# |    critic_loss     | 0.0302   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 32313    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 468      |
# |    ep_rew_mean     | 1.26     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 140      |
# |    time_elapsed    | 279      |
# |    total_timesteps | 39314    |
# | train/             |          |
# |    actor_loss      | -10.5    |
# |    critic_loss     | 3.21     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 34313    |
# ---------------------------------
# Eval num_timesteps=40000, episode_reward=6.84 +/- 28.61
# Episode length: 432.60 +/- 117.16
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 433      |
# |    mean_reward     | 6.84     |
# | time/              |          |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | -11.2    |
# |    critic_loss     | 0.102    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 34999    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 467      |
# |    ep_rew_mean     | 1.56     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 139      |
# |    time_elapsed    | 295      |
# |    total_timesteps | 41131    |
# | train/             |          |
# |    actor_loss      | -10.2    |
# |    critic_loss     | 0.0311   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 36130    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 469      |
# |    ep_rew_mean     | 1.75     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 138      |
# |    time_elapsed    | 312      |
# |    total_timesteps | 43116    |
# | train/             |          |
# |    actor_loss      | -10.9    |
# |    critic_loss     | 0.0588   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 38115    |
# ---------------------------------
# Eval num_timesteps=45000, episode_reward=1.27 +/- 24.50
# Episode length: 453.60 +/- 107.20
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 454      |
# |    mean_reward     | 1.27     |
# | time/              |          |
# |    total_timesteps | 45000    |
# | train/             |          |
# |    actor_loss      | -10.1    |
# |    critic_loss     | 0.0216   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 470      |
# |    ep_rew_mean     | 1.48     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 137      |
# |    time_elapsed    | 328      |
# |    total_timesteps | 45116    |
# | train/             |          |
# |    actor_loss      | -10.6    |
# |    critic_loss     | 0.0358   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 40115    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 466      |
# |    ep_rew_mean     | 2.28     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 137      |
# |    time_elapsed    | 340      |
# |    total_timesteps | 46587    |
# | train/             |          |
# |    actor_loss      | -11      |
# |    critic_loss     | 0.0309   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 41586    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 458      |
# |    ep_rew_mean     | 3.38     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 136      |
# |    time_elapsed    | 349      |
# |    total_timesteps | 47758    |
# | train/             |          |
# |    actor_loss      | -11      |
# |    critic_loss     | 0.0276   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 42757    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 453      |
# |    ep_rew_mean     | 3.93     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 136      |
# |    time_elapsed    | 360      |
# |    total_timesteps | 49297    |
# | train/             |          |
# |    actor_loss      | -11.5    |
# |    critic_loss     | 0.222    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 44296    |
# ---------------------------------
# Eval num_timesteps=50000, episode_reward=-0.23 +/- 27.54
# Episode length: 460.40 +/- 99.86
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 460      |
# |    mean_reward     | -0.232   |
# | time/              |          |
# |    total_timesteps | 50000    |
# | train/             |          |
# |    actor_loss      | -9.99    |
# |    critic_loss     | 0.0222   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 44999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 447      |
# |    ep_rew_mean     | 5.02     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 135      |
# |    time_elapsed    | 374      |
# |    total_timesteps | 50676    |
# | train/             |          |
# |    actor_loss      | -12.2    |
# |    critic_loss     | 0.0302   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 45675    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 442      |
# |    ep_rew_mean     | 6.06     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 135      |
# |    time_elapsed    | 384      |
# |    total_timesteps | 52227    |
# | train/             |          |
# |    actor_loss      | -11.4    |
# |    critic_loss     | 0.0399   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47226    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 438      |
# |    ep_rew_mean     | 7.1      |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 135      |
# |    time_elapsed    | 397      |
# |    total_timesteps | 53764    |
# | train/             |          |
# |    actor_loss      | -11.5    |
# |    critic_loss     | 0.0684   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 48763    |
# ---------------------------------
# Eval num_timesteps=55000, episode_reward=10.87 +/- 40.14
# Episode length: 313.30 +/- 190.67
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 313      |
# |    mean_reward     | 10.9     |
# | time/              |          |
# |    total_timesteps | 55000    |
# | train/             |          |
# |    actor_loss      | -12.2    |
# |    critic_loss     | 0.0493   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49999    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 433      |
# |    ep_rew_mean     | 7.56     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 134      |
# |    time_elapsed    | 410      |
# |    total_timesteps | 55313    |
# | train/             |          |
# |    actor_loss      | -11.7    |
# |    critic_loss     | 0.0839   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 50312    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 430      |
# |    ep_rew_mean     | 8.07     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 134      |
# |    time_elapsed    | 422      |
# |    total_timesteps | 56969    |
# | train/             |          |
# |    actor_loss      | -11.5    |
# |    critic_loss     | 0.0322   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 51968    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 426      |
# |    ep_rew_mean     | 9.12     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 134      |
# |    time_elapsed    | 436      |
# |    total_timesteps | 58644    |
# | train/             |          |
# |    actor_loss      | -12.3    |
# |    critic_loss     | 0.0592   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 53643    |
# ---------------------------------
# Eval num_timesteps=60000, episode_reward=8.22 +/- 37.11
# Episode length: 322.70 +/- 217.65
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 323      |
# |    mean_reward     | 8.22     |
# | time/              |          |
# |    total_timesteps | 60000    |
# | train/             |          |
# |    actor_loss      | -12.1    |
# |    critic_loss     | 0.0255   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 54999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 422      |
# |    ep_rew_mean     | 9.57     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 134      |
# |    time_elapsed    | 449      |
# |    total_timesteps | 60247    |
# | train/             |          |
# |    actor_loss      | -12.1    |
# |    critic_loss     | 0.0301   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 55246    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 418      |
# |    ep_rew_mean     | 10.1     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 134      |
# |    time_elapsed    | 458      |
# |    total_timesteps | 61596    |
# | train/             |          |
# |    actor_loss      | -11.7    |
# |    critic_loss     | 0.0461   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 56595    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 418      |
# |    ep_rew_mean     | 10       |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 134      |
# |    time_elapsed    | 474      |
# |    total_timesteps | 63596    |
# | train/             |          |
# |    actor_loss      | -12.1    |
# |    critic_loss     | 0.0355   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 58595    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 416      |
# |    ep_rew_mean     | 10.6     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 133      |
# |    time_elapsed    | 483      |
# |    total_timesteps | 64770    |
# | train/             |          |
# |    actor_loss      | -12.2    |
# |    critic_loss     | 0.0445   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 59769    |
# ---------------------------------
# Eval num_timesteps=65000, episode_reward=21.79 +/- 36.13
# Episode length: 257.80 +/- 201.94
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 258      |
# |    mean_reward     | 21.8     |
# | time/              |          |
# |    total_timesteps | 65000    |
# | train/             |          |
# |    actor_loss      | -12.8    |
# |    critic_loss     | 0.0282   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 59999    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 410      |
# |    ep_rew_mean     | 11.1     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 133      |
# |    time_elapsed    | 494      |
# |    total_timesteps | 66002    |
# | train/             |          |
# |    actor_loss      | -12.9    |
# |    critic_loss     | 0.053    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 61001    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 405      |
# |    ep_rew_mean     | 11.7     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 133      |
# |    time_elapsed    | 502      |
# |    total_timesteps | 67254    |
# | train/             |          |
# |    actor_loss      | -13.5    |
# |    critic_loss     | 0.0346   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 62253    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 391      |
# |    ep_rew_mean     | 13.4     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 133      |
# |    time_elapsed    | 504      |
# |    total_timesteps | 67481    |
# | train/             |          |
# |    actor_loss      | -13.5    |
# |    critic_loss     | 0.0666   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 62480    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 385      |
# |    ep_rew_mean     | 14.5     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 133      |
# |    time_elapsed    | 512      |
# |    total_timesteps | 68449    |
# | train/             |          |
# |    actor_loss      | -13.1    |
# |    critic_loss     | 0.0212   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 63448    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 381      |
# |    ep_rew_mean     | 15.1     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 133      |
# |    time_elapsed    | 524      |
# |    total_timesteps | 69852    |
# | train/             |          |
# |    actor_loss      | -13.4    |
# |    critic_loss     | 0.0567   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 64851    |
# ---------------------------------
# Eval num_timesteps=70000, episode_reward=21.68 +/- 28.57
# Episode length: 288.10 +/- 214.94
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 288      |
# |    mean_reward     | 21.7     |
# | time/              |          |
# |    total_timesteps | 70000    |
# | train/             |          |
# |    actor_loss      | -13.2    |
# |    critic_loss     | 0.046    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 64999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 385      |
# |    ep_rew_mean     | 14.5     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 132      |
# |    time_elapsed    | 540      |
# |    total_timesteps | 71852    |
# | train/             |          |
# |    actor_loss      | -12.9    |
# |    critic_loss     | 0.0141   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 66851    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 378      |
# |    ep_rew_mean     | 15.6     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 132      |
# |    time_elapsed    | 550      |
# |    total_timesteps | 73107    |
# | train/             |          |
# |    actor_loss      | -13.3    |
# |    critic_loss     | 0.0812   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 68106    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 374      |
# |    ep_rew_mean     | 16.2     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 132      |
# |    time_elapsed    | 563      |
# |    total_timesteps | 74721    |
# | train/             |          |
# |    actor_loss      | -13.2    |
# |    critic_loss     | 0.0146   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 69720    |
# ---------------------------------
# Eval num_timesteps=75000, episode_reward=-0.90 +/- 27.42
# Episode length: 409.60 +/- 180.82
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 410      |
# |    mean_reward     | -0.904   |
# | time/              |          |
# |    total_timesteps | 75000    |
# | train/             |          |
# |    actor_loss      | -13      |
# |    critic_loss     | 0.0654   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 69999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 362      |
# |    ep_rew_mean     | 17.8     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 132      |
# |    time_elapsed    | 571      |
# |    total_timesteps | 75522    |
# | train/             |          |
# |    actor_loss      | -13.6    |
# |    critic_loss     | 0.0516   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 70521    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 360      |
# |    ep_rew_mean     | 17.8     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 131      |
# |    time_elapsed    | 584      |
# |    total_timesteps | 77083    |
# | train/             |          |
# |    actor_loss      | -13.8    |
# |    critic_loss     | 0.0302   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 72082    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 350      |
# |    ep_rew_mean     | 19       |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 131      |
# |    time_elapsed    | 592      |
# |    total_timesteps | 78156    |
# | train/             |          |
# |    actor_loss      | -13.3    |
# |    critic_loss     | 0.0208   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 73155    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 342      |
# |    ep_rew_mean     | 20.1     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 132      |
# |    time_elapsed    | 600      |
# |    total_timesteps | 79357    |
# | train/             |          |
# |    actor_loss      | -14.2    |
# |    critic_loss     | 0.0577   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 74356    |
# ---------------------------------
# Eval num_timesteps=80000, episode_reward=22.46 +/- 27.28
# Episode length: 324.70 +/- 182.09
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 325      |
# |    mean_reward     | 22.5     |
# | time/              |          |
# |    total_timesteps | 80000    |
# | train/             |          |
# |    actor_loss      | -13.8    |
# |    critic_loss     | 0.0295   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 74999    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 338      |
# |    ep_rew_mean     | 20.6     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 131      |
# |    time_elapsed    | 611      |
# |    total_timesteps | 80381    |
# | train/             |          |
# |    actor_loss      | -13.4    |
# |    critic_loss     | 0.0311   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 75380    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 334      |
# |    ep_rew_mean     | 21.2     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 131      |
# |    time_elapsed    | 617      |
# |    total_timesteps | 81162    |
# | train/             |          |
# |    actor_loss      | -13.5    |
# |    critic_loss     | 0.0157   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 76161    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 326      |
# |    ep_rew_mean     | 22.3     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 131      |
# |    time_elapsed    | 623      |
# |    total_timesteps | 81850    |
# | train/             |          |
# |    actor_loss      | -14.4    |
# |    critic_loss     | 0.0553   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 76849    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 323      |
# |    ep_rew_mean     | 22.8     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 131      |
# |    time_elapsed    | 631      |
# |    total_timesteps | 82974    |
# | train/             |          |
# |    actor_loss      | -14.9    |
# |    critic_loss     | 0.074    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 77973    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 321      |
# |    ep_rew_mean     | 22.9     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 131      |
# |    time_elapsed    | 641      |
# |    total_timesteps | 84312    |
# | train/             |          |
# |    actor_loss      | -13.3    |
# |    critic_loss     | 0.155    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 79311    |
# ---------------------------------
# Eval num_timesteps=85000, episode_reward=3.78 +/- 23.21
# Episode length: 422.40 +/- 157.14
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 422      |
# |    mean_reward     | 3.78     |
# | time/              |          |
# |    total_timesteps | 85000    |
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 0.0213   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 79999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 319      |
# |    ep_rew_mean     | 22.9     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 130      |
# |    time_elapsed    | 654      |
# |    total_timesteps | 85619    |
# | train/             |          |
# |    actor_loss      | -14      |
# |    critic_loss     | 0.073    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 80618    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 318      |
# |    ep_rew_mean     | 23       |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 130      |
# |    time_elapsed    | 665      |
# |    total_timesteps | 87158    |
# | train/             |          |
# |    actor_loss      | -14      |
# |    critic_loss     | 0.258    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 82157    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 317      |
# |    ep_rew_mean     | 23       |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 131      |
# |    time_elapsed    | 676      |
# |    total_timesteps | 88713    |
# | train/             |          |
# |    actor_loss      | -13.7    |
# |    critic_loss     | 0.0262   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 83712    |
# ---------------------------------
# Eval num_timesteps=90000, episode_reward=9.55 +/- 26.50
# Episode length: 377.00 +/- 188.46
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 377      |
# |    mean_reward     | 9.55     |
# | time/              |          |
# |    total_timesteps | 90000    |
# | train/             |          |
# |    actor_loss      | -13.5    |
# |    critic_loss     | 0.0299   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 84999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 314      |
# |    ep_rew_mean     | 23.6     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 131      |
# |    time_elapsed    | 686      |
# |    total_timesteps | 90053    |
# | train/             |          |
# |    actor_loss      | -15.5    |
# |    critic_loss     | 0.0841   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 85052    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 310      |
# |    ep_rew_mean     | 24.2     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 130      |
# |    time_elapsed    | 696      |
# |    total_timesteps | 91275    |
# | train/             |          |
# |    actor_loss      | -15.7    |
# |    critic_loss     | 0.0312   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 86274    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 305      |
# |    ep_rew_mean     | 24.2     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 130      |
# |    time_elapsed    | 703      |
# |    total_timesteps | 92066    |
# | train/             |          |
# |    actor_loss      | -15.1    |
# |    critic_loss     | 0.0836   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 87065    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 297      |
# |    ep_rew_mean     | 25.4     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 130      |
# |    time_elapsed    | 713      |
# |    total_timesteps | 93340    |
# | train/             |          |
# |    actor_loss      | -13.5    |
# |    critic_loss     | 0.0298   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 88339    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 302      |
# |    ep_rew_mean     | 24.4     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 131      |
# |    time_elapsed    | 723      |
# |    total_timesteps | 94959    |
# | train/             |          |
# |    actor_loss      | -14.7    |
# |    critic_loss     | 0.0518   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 89958    |
# ---------------------------------
# Eval num_timesteps=95000, episode_reward=21.79 +/- 35.22
# Episode length: 297.60 +/- 194.85
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 298      |
# |    mean_reward     | 21.8     |
# | time/              |          |
# |    total_timesteps | 95000    |
# | train/             |          |
# |    actor_loss      | -14      |
# |    critic_loss     | 0.0237   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 89999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 305      |
# |    ep_rew_mean     | 23.8     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 130      |
# |    time_elapsed    | 736      |
# |    total_timesteps | 96493    |
# | train/             |          |
# |    actor_loss      | -14.7    |
# |    critic_loss     | 0.0655   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 91492    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 305      |
# |    ep_rew_mean     | 24.4     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 130      |
# |    time_elapsed    | 746      |
# |    total_timesteps | 97708    |
# | train/             |          |
# |    actor_loss      | -15.3    |
# |    critic_loss     | 0.144    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 92707    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 313      |
# |    ep_rew_mean     | 23.8     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 131      |
# |    time_elapsed    | 752      |
# |    total_timesteps | 98792    |
# | train/             |          |
# |    actor_loss      | -15.4    |
# |    critic_loss     | 0.08     |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 93791    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 313      |
# |    ep_rew_mean     | 23.8     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 131      |
# |    time_elapsed    | 759      |
# |    total_timesteps | 99783    |
# | train/             |          |
# |    actor_loss      | -14.7    |
# |    critic_loss     | 0.0268   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 94782    |
# ---------------------------------
# Eval num_timesteps=100000, episode_reward=14.00 +/- 30.08
# Episode length: 321.30 +/- 219.27
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 321      |
# |    mean_reward     | 14       |
# | time/              |          |
# |    total_timesteps | 100000   |
# | train/             |          |
# |    actor_loss      | -14.8    |
# |    critic_loss     | 0.0549   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 94999    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 319      |
# |    ep_rew_mean     | 22.7     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 130      |
# |    time_elapsed    | 777      |
# |    total_timesteps | 101783   |
# | train/             |          |
# |    actor_loss      | -14.8    |
# |    critic_loss     | 0.0724   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 96782    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 309      |
# |    ep_rew_mean     | 24.3     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 131      |
# |    time_elapsed    | 783      |
# |    total_timesteps | 102765   |
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 0.0254   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 97764    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 306      |
# |    ep_rew_mean     | 25.4     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 131      |
# |    time_elapsed    | 791      |
# |    total_timesteps | 103710   |
# | train/             |          |
# |    actor_loss      | -15      |
# |    critic_loss     | 0.4      |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 98709    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 292      |
# |    ep_rew_mean     | 27       |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 131      |
# |    time_elapsed    | 793      |
# |    total_timesteps | 103959   |
# | train/             |          |
# |    actor_loss      | -14.7    |
# ...
# |    actor_loss      | -13.9    |
# |    critic_loss     | 0.0338   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 473951   |
# ---------------------------------
# Eval num_timesteps=480000, episode_reward=30.27 +/- 31.49
# Episode length: 216.50 +/- 188.17
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 216      |
# |    mean_reward     | 30.3     |
# | time/              |          |
# |    total_timesteps | 480000   |
# | train/             |          |
# |    actor_loss      | -15.7    |
# |    critic_loss     | 0.0311   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 474999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 237      |
# |    ep_rew_mean     | 33.3     |
# | time/              |          |
# |    episodes        | 1764     |
# |    fps             | 128      |
# |    time_elapsed    | 3747     |
# |    total_timesteps | 480215   |
# | train/             |          |
# |    actor_loss      | -13.6    |
# |    critic_loss     | 0.0165   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 475214   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 238      |
# |    ep_rew_mean     | 32.8     |
# | time/              |          |
# |    episodes        | 1768     |
# |    fps             | 128      |
# |    time_elapsed    | 3755     |
# |    total_timesteps | 481419   |
# | train/             |          |
# |    actor_loss      | -14.2    |
# |    critic_loss     | 0.146    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 476418   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 239      |
# |    ep_rew_mean     | 32.3     |
# | time/              |          |
# |    episodes        | 1772     |
# |    fps             | 128      |
# |    time_elapsed    | 3763     |
# |    total_timesteps | 482390   |
# | train/             |          |
# |    actor_loss      | -13.7    |
# |    critic_loss     | 0.0361   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 477389   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 229      |
# |    ep_rew_mean     | 33.4     |
# | time/              |          |
# |    episodes        | 1776     |
# |    fps             | 128      |
# |    time_elapsed    | 3766     |
# |    total_timesteps | 482817   |
# | train/             |          |
# |    actor_loss      | -13.9    |
# |    critic_loss     | 0.0338   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 477816   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 234      |
# |    ep_rew_mean     | 32.8     |
# | time/              |          |
# |    episodes        | 1780     |
# |    fps             | 128      |
# |    time_elapsed    | 3773     |
# |    total_timesteps | 483784   |
# | train/             |          |
# |    actor_loss      | -14.9    |
# |    critic_loss     | 0.0726   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 478783   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 31.7     |
# | time/              |          |
# |    episodes        | 1784     |
# |    fps             | 128      |
# |    time_elapsed    | 3780     |
# |    total_timesteps | 484897   |
# | train/             |          |
# |    actor_loss      | -15.2    |
# |    critic_loss     | 0.0248   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 479896   |
# ---------------------------------
# Eval num_timesteps=485000, episode_reward=27.68 +/- 27.35
# Episode length: 261.20 +/- 201.38
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 261      |
# |    mean_reward     | 27.7     |
# | time/              |          |
# |    total_timesteps | 485000   |
# | train/             |          |
# |    actor_loss      | -15.4    |
# |    critic_loss     | 0.0272   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 479999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 246      |
# |    ep_rew_mean     | 31.1     |
# | time/              |          |
# |    episodes        | 1788     |
# |    fps             | 128      |
# |    time_elapsed    | 3793     |
# |    total_timesteps | 486316   |
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 0.0184   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 481315   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 243      |
# |    ep_rew_mean     | 31.7     |
# | time/              |          |
# |    episodes        | 1792     |
# |    fps             | 128      |
# |    time_elapsed    | 3799     |
# |    total_timesteps | 487093   |
# | train/             |          |
# |    actor_loss      | -14.8    |
# |    critic_loss     | 0.0662   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 482092   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 246      |
# |    ep_rew_mean     | 31.1     |
# | time/              |          |
# |    episodes        | 1796     |
# |    fps             | 128      |
# |    time_elapsed    | 3805     |
# |    total_timesteps | 487881   |
# | train/             |          |
# |    actor_loss      | -15.1    |
# |    critic_loss     | 0.0587   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 482880   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 242      |
# |    ep_rew_mean     | 31.7     |
# | time/              |          |
# |    episodes        | 1800     |
# |    fps             | 128      |
# |    time_elapsed    | 3808     |
# |    total_timesteps | 488180   |
# | train/             |          |
# |    actor_loss      | -14.2    |
# |    critic_loss     | 0.061    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 483179   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 233      |
# |    ep_rew_mean     | 32.8     |
# | time/              |          |
# |    episodes        | 1804     |
# |    fps             | 128      |
# |    time_elapsed    | 3809     |
# |    total_timesteps | 488548   |
# | train/             |          |
# |    actor_loss      | -15.2    |
# |    critic_loss     | 0.0514   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 483547   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 228      |
# |    ep_rew_mean     | 33.9     |
# | time/              |          |
# |    episodes        | 1808     |
# |    fps             | 128      |
# |    time_elapsed    | 3813     |
# |    total_timesteps | 489156   |
# | train/             |          |
# |    actor_loss      | -14.8    |
# |    critic_loss     | 0.0375   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 484155   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | 33.9     |
# | time/              |          |
# |    episodes        | 1812     |
# |    fps             | 128      |
# |    time_elapsed    | 3816     |
# |    total_timesteps | 489489   |
# | train/             |          |
# |    actor_loss      | -15.7    |
# |    critic_loss     | 0.0356   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 484488   |
# ---------------------------------
# Eval num_timesteps=490000, episode_reward=34.77 +/- 31.80
# Episode length: 180.30 +/- 172.50
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 180      |
# |    mean_reward     | 34.8     |
# | time/              |          |
# |    total_timesteps | 490000   |
# | train/             |          |
# |    actor_loss      | -14.8    |
# |    critic_loss     | 0.079    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 484999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 224      |
# |    ep_rew_mean     | 34.5     |
# | time/              |          |
# |    episodes        | 1816     |
# |    fps             | 128      |
# |    time_elapsed    | 3828     |
# |    total_timesteps | 490848   |
# | train/             |          |
# |    actor_loss      | -15      |
# |    critic_loss     | 0.0734   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 485847   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 218      |
# |    ep_rew_mean     | 35.6     |
# | time/              |          |
# |    episodes        | 1820     |
# |    fps             | 128      |
# |    time_elapsed    | 3834     |
# |    total_timesteps | 491528   |
# | train/             |          |
# |    actor_loss      | -15.7    |
# |    critic_loss     | 0.0893   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 486527   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 221      |
# |    ep_rew_mean     | 35       |
# | time/              |          |
# |    episodes        | 1824     |
# |    fps             | 128      |
# |    time_elapsed    | 3842     |
# |    total_timesteps | 492758   |
# | train/             |          |
# |    actor_loss      | -15.2    |
# |    critic_loss     | 0.0286   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 487757   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 225      |
# |    ep_rew_mean     | 35       |
# | time/              |          |
# |    episodes        | 1828     |
# |    fps             | 128      |
# |    time_elapsed    | 3852     |
# |    total_timesteps | 493957   |
# | train/             |          |
# |    actor_loss      | -14.6    |
# |    critic_loss     | 0.0547   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 488956   |
# ---------------------------------
# Eval num_timesteps=495000, episode_reward=27.63 +/- 27.80
# Episode length: 240.80 +/- 213.56
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 241      |
# |    mean_reward     | 27.6     |
# | time/              |          |
# |    total_timesteps | 495000   |
# | train/             |          |
# |    actor_loss      | -14.6    |
# |    critic_loss     | 0.0413   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 489999   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 228      |
# |    ep_rew_mean     | 35       |
# | time/              |          |
# |    episodes        | 1832     |
# |    fps             | 128      |
# |    time_elapsed    | 3862     |
# |    total_timesteps | 495009   |
# | train/             |          |
# |    actor_loss      | -15.1    |
# |    critic_loss     | 0.0786   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 490008   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 221      |
# |    ep_rew_mean     | 35.5     |
# | time/              |          |
# |    episodes        | 1836     |
# |    fps             | 128      |
# |    time_elapsed    | 3867     |
# |    total_timesteps | 495639   |
# | train/             |          |
# |    actor_loss      | -15.6    |
# |    critic_loss     | 0.0374   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 490638   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 217      |
# |    ep_rew_mean     | 36.1     |
# | time/              |          |
# |    episodes        | 1840     |
# |    fps             | 128      |
# |    time_elapsed    | 3869     |
# |    total_timesteps | 496030   |
# | train/             |          |
# |    actor_loss      | -15.2    |
# |    critic_loss     | 0.0991   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 491029   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 220      |
# |    ep_rew_mean     | 35.6     |
# | time/              |          |
# |    episodes        | 1844     |
# |    fps             | 128      |
# |    time_elapsed    | 3881     |
# |    total_timesteps | 497631   |
# | train/             |          |
# |    actor_loss      | -15      |
# |    critic_loss     | 0.0291   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 492630   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 221      |
# |    ep_rew_mean     | 35.5     |
# | time/              |          |
# |    episodes        | 1848     |
# |    fps             | 128      |
# |    time_elapsed    | 3888     |
# |    total_timesteps | 498468   |
# | train/             |          |
# |    actor_loss      | -14.5    |
# |    critic_loss     | 0.0437   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 493467   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 223      |
# |    ep_rew_mean     | 35.5     |
# | time/              |          |
# |    episodes        | 1852     |
# |    fps             | 128      |
# |    time_elapsed    | 3895     |
# |    total_timesteps | 499468   |
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 0.0255   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 494467   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 217      |
# |    ep_rew_mean     | 36.1     |
# | time/              |          |
# |    episodes        | 1856     |
# |    fps             | 128      |
# |    time_elapsed    | 3898     |
# |    total_timesteps | 499775   |
# | train/             |          |
# |    actor_loss      | -15.1    |
# |    critic_loss     | 0.0282   |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 494774   |
# ---------------------------------
# Eval num_timesteps=500000, episode_reward=20.86 +/- 29.65
# Episode length: 315.00 +/- 187.76
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 315      |
# |    mean_reward     | 20.9     |
# | time/              |          |
# |    total_timesteps | 500000   |
# | train/             |          |
# |    actor_loss      | -15.4    |
# |    critic_loss     | 0.039    |
# |    ent_coef        | 0.1      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 494999   |
# ---------------------------------
# Trening zakończony. Model zapisany do models/rolling_ball_final.zip

# %%
import matplotlib.pyplot as plt

evaluations  = np.load("logs/evaluations.npz")
timesteps    = evaluations["timesteps"]
mean_rewards = evaluations["results"].mean(axis=1)
std_rewards  = evaluations["results"].std(axis=1)

fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(timesteps, mean_rewards, color="steelblue", label="Średnia nagroda (10 epizodów)")
ax.fill_between(
    timesteps,
    mean_rewards - std_rewards,
    mean_rewards + std_rewards,
    alpha=0.25, color="steelblue",
)
ax.axhline(0, color="gray", linewidth=0.7, linestyle="--")
ax.set_xlabel("Kroki (timesteps)")
ax.set_ylabel("Nagroda epizodu")
ax.set_title("Krzywa uczenia – SAC – Rolling Ball Navigator")
ax.legend()
ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig("training_curve.png", dpi=150)
plt.show()

# %% [markdown]
# ## 3. Ewaluacja
#
# Wczytujemy najlepszy model zapisany przez `EvalCallback` i uruchamiamy go deterministycznie na zbiorze epizodów ewaluacyjnych. Mierzymy skuteczność (odsetek epizodów zakończonych sukcesem), średnią nagrodę i średnią liczbę kroków potrzebnych do dotarcia do celu.

# %%
from stable_baselines3 import SAC

model = SAC.load("models/best_model")

N_EVAL = 30
successes  = 0
ep_rewards = []
ep_lengths = []

eval_env = RollingBallEnv()
for ep in range(N_EVAL):
    obs, _ = eval_env.reset(seed=ep)
    total_reward = 0.0
    while True:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = eval_env.step(action)
        total_reward += reward
        if terminated or truncated:
            if terminated:
                successes += 1
            ep_rewards.append(total_reward)
            ep_lengths.append(info["step"])
            break
eval_env.close()

print(f"Wyniki ewaluacji ({N_EVAL} epizodów):")
print(f"  Skuteczność (dotarcie do celu): {successes / N_EVAL * 100:.1f}%")
print(f"  Średnia nagroda:                {np.mean(ep_rewards):.2f} ± {np.std(ep_rewards):.2f}")
print(f"  Średnia liczba kroków:          {np.mean(ep_lengths):.1f} ± {np.std(ep_lengths):.1f}")
# Out:
# Wyniki ewaluacji (30 epizodów):
#   Skuteczność (dotarcie do celu): 66.7%
#   Średnia nagroda:                30.51 ± 28.27
#   Średnia liczba kroków:          241.1 ± 189.2

# %%
from PIL import Image as PILImage
from IPython.display import display, Image
from stable_baselines3 import SAC

model   = SAC.load("models/best_model")
rec_env = RollingBallEnv(render_mode="rgb_array")

obs, _ = rec_env.reset(seed=0)
frames = [rec_env.render()]
while True:
    action, _ = model.predict(obs, deterministic=True)
    obs, _, terminated, truncated, _ = rec_env.step(action)
    frames.append(rec_env.render())
    if terminated or truncated:
        break
rec_env.close()

pil_frames = [PILImage.fromarray(f).resize((300, 300)) for f in frames]
pil_frames[0].save(
    "episode.gif",
    save_all=True,
    append_images=pil_frames[1:],
    duration=33,
    loop=0,
)
print(f"Nagrany epizod: {len(frames)} klatek ({len(frames) / 30:.1f} s @ 30 fps)")
display(Image("episode.gif"))
# Out:
# Nagrany epizod: 501 klatek (16.7 s @ 30 fps)

# %%
# ── Tryb na żywo (pygame window) ─────────────────────────────────────────────
# Uruchom tę komórkę oddzielnie. Otwiera okno pygame z agentem grającym w czasie
# rzeczywistym. Zamknij okno lub przerwij kernel aby zakończyć.

from stable_baselines3 import SAC

model    = SAC.load("models/best_model")
live_env = RollingBallEnv(render_mode="human")

for episode in range(10):
    obs, _ = live_env.reset()
    while True:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, terminated, truncated, _ = live_env.step(action)
        if terminated or truncated:
            break

live_env.close()
